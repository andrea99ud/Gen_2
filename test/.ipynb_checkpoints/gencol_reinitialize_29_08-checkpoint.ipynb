# %%
def plot(data):
    figure, axis = plt.subplots(2, 3)

    axis[0][0].plot(data.cost)
    axis[0][0].set_title("cost transport")
    #axis[0].set_ylim((0, 2))

    axis[0][1].plot(data.time_child)
    axis[0][1].set_title("time to find a child")
    #axis[1].set_ylim((0, 0.01))

    axis[0][2].plot(data.time_model)
    axis[0][2].set_title("LP time")
    #axis[2].set_ylim((0, 0.5))

    axis[1][0].plot(data.n_children)
    axis[1][0].set_title("number sites")

    axis[1][1].boxplot(data.memory)
    axis[1][1].set_title("number of memory slot")

    axis[1][2].plot(np.array(data.cost[:-1])-np.array(data.cost[1:]))
    axis[1][2].set_title("improvements")


    figure.set_size_inches(18.5, 10.5)

    plt.show()

    print(f"the final cost is {data.cost[-1]}")
    
def stats(data):
    print("obj_cost: ", data.cost[-1])
    print("average_memory: ", np.mean(data.memory))
    print("average_time_LP: ", np.mean(data.time_model))
    print("average_children_sampled: ", np.mean(data.children_sampled))

# %%
import matplotlib.pyplot as plt
import numpy as np
from tqdm import tqdm
from PIL import Image
import scipy.sparse as sp
import scipy
import time
import itertools
import scipy
import cvxpy as cp
import random
import matplotlib
import math
import gurobipy as gp
from gurobipy import GRB

def create_array(orig_array, percentage):
    # Compute the number of unique rows we'll use
    num_rows = int(orig_array.shape[0] *percentage)
    
    # If num_rows is zero, we should at least select one row.
    num_rows = max(1, num_rows)
    
    # Randomly select 'num_rows' row indices without replacement
    unique_indices = np.random.choice(orig_array.shape[0], size=num_rows, replace=False)

    # Select the unique rows from the original array
    unique_rows = orig_array[unique_indices, :]
    
    # Now, we'll need to repeat these rows to fill the new array
    num_repeats = int(np.ceil(orig_array.shape[0] / float(num_rows)))

    # Repeat the unique rows to create a new array
    new_array = np.repeat(unique_rows, num_repeats, axis=0)
    
    # Make sure the new array has the same number of rows as the original array
    new_array = new_array[:orig_array.shape[0], :]
    
    return new_array

class Genetic_Algorithm:
    def __init__(self, img_list):
        
        
        self.N = img_list[0].shape[0]
        self.dim = len(img_list[0].shape)
        self.imgs = np.array([img.flatten() for img in img_list])
        self.b_eq = np.concatenate(self.imgs)
        self.non_zero_indices = []
        self.n_imgs = len(self.imgs)
        
        
         #stats
        self.cost = []
        self.time_child = []
        self.children_sampled = []
        self.time_model = []
        self.len_children = []
        self.n_children = []
        self.memory=[]
        
        start = time.time()
        print("initializing omega...")
        self.initialize_omega(add_diag=False)
        print("omega initialized in %5.3f. s" %(time.time()-start))
        
        start = time.time()
        print("initializing cost vector...")
        self.current_cost_vector = self.get_cost(self.active_indices)
        print("cost vector initialized in %5.3f. s" %(time.time()-start))
       
        start = time.time()
        print("initializing full model...")
        self.initialize_model()
        print("full model initialized in %5.3f. s" %(time.time()-start))

       
        
    def initialize_omega(self, add_diag=False):
        #the north west rule is used to initialise omega
        #we start with the first pixel of each image
        indices = np.zeros(self.n_imgs)
        omega = np.array(indices.copy())
        b = np.array([img[0] for img in self.imgs])

        current_gamma = [np.min(b)]
        while np.min(indices) < self.N**self.dim-1:
            gamma = np.min(b)
            b-=gamma
            low = np.where(b < 1e-9)[0]
            indices[low] +=1
            indices = np.clip(indices, a_min=0, a_max=self.N**self.dim-1)
            b[low] = self.imgs[low,indices[low].astype('int')]
            
            omega = np.vstack((omega,indices.copy()))
            current_gamma.append(gamma)
        
        self.current_gamma = np.array(current_gamma)
        self.active_indices = np.array(omega).astype('int')
        if add_diag:
            self.current_gamma = np.concatenate((self.current_gamma, np.zeros(self.N**self.dim)))
            self.active_indices = np.vstack((self.active_indices, np.repeat(np.arange(0,self.N**self.dim)[:, np.newaxis], self.n_imgs, axis=1)))
            
        
        
        
        
    def initialize_model(self):
        start = time.time()
        indices_row = np.array([])
        indices_col = np.array([])
        for i in range(self.n_imgs):
            for indices in range(self.N**self.dim):
                gamma_indices = np.where(self.active_indices.transpose()[i] == indices)[0]
                indices_row = np.concatenate((indices_row, gamma_indices))
                indices_col = np.concatenate((indices_col, np.ones(len(gamma_indices))*(indices+i*(self.N**self.dim))))

        A_eq = sp.csr_matrix((np.ones(len(indices_col)), (indices_col, indices_row)), shape=( (self.N**self.dim)*self.n_imgs, len(self.active_indices)))
        
        self.m = gp.Model("model")
        self.gamma = self.m.addMVar(shape=len(self.current_cost_vector), vtype=GRB.CONTINUOUS, name="gamma")
        self.m.setObjective(self.current_cost_vector @ self.gamma, GRB.MINIMIZE)
        print(len(self.current_cost_vector))
        self.m.Params.OutputFlag = True
        self.m.Params.FeasibilityTol = 1e-8
        
        self.m.addConstr(A_eq @ self.gamma == self.b_eq, name="eq_c")
        self.m.Params.LPWarmStart=2
        self.gamma.PStart = self.current_gamma
        #self.constraints.DStart = self.current_kantorovich
        self.m.optimize()
        primal_solution = np.array(self.gamma.X)
        dual_solution = np.array(self.m.PI)
        self.time_model.append(time.time()-start)
        self.cost.append(self.m.ObjVal)
        self.current_gamma = primal_solution
        self.current_kantorovich = dual_solution
        self.constraints_RMP=A_eq
        
  

    def barycentric_distance(self, indices_list):
        # mean squared deviation from the classical barycenter of the xi
        #rescale x and y to be in [0,1]
       
        barycenter = np.sum(indices_list/self.N, axis=0)/self.n_imgs
        
        barycenter_cost = np.sum([np.sum((x - barycenter) ** 2, axis=0)/self.n_imgs for x in indices_list/self.N], axis=0)
      
        return barycenter_cost

    def get_cost(self, vector):
        #for each pair of active pixels, compute the cost of moving the first pixel to the second
        indices_list = []
        for i in range(self.n_imgs):
            indices_list.append(np.array(np.unravel_index(vector.transpose()[i], tuple([self.N for i in range(self.dim)]))))
        cost_vector = self.barycentric_distance(np.array(indices_list))
        return cost_vector

    def compute_gain(self, cost, children):
        gain = np.sum([self.current_kantorovich[i*(self.N**self.dim):(i+1)*(self.N**self.dim)][children.transpose()[i]] for i in range(self.n_imgs)], axis=0)-cost
        return gain

    def find_best_child(self):
        parent = self.non_zero_indices.copy().transpose()
       
        parent = create_array(parent, self.parent_to_children)
       
        index = random.sample(range(0, self.n_imgs), self.parent_changed)
        parent[index] = np.random.randint(0, self.N**self.dim, size=len(parent[1]))
        
        children = parent.copy().transpose()
        
        gain = self.compute_gain(self.get_cost(children), children)
        
        best_children = children[np.where(gain > 0)[0]]
       
        #now take the best turnover_rate% or just some random turnover_rate
        if not self.random_selection:                  
            best_children = children[np.argsort(gain)[-int(best_children.shape[0]*self.turnover_rate):]]
        else:
            chosen_children = np.random.choice(best_children.shape[0], size=int(best_children.shape[0]*self.turnover_rate), replace=False)
            best_children = best_children[chosen_children]
        
        if self.add_neighbours:
            for i in self.neighbours:
                parent[index] = np.clip(self.non_zero_indices.copy().transpose()[index]+i, 0, self.N**2-1)
                children = parent.copy().transpose()
                gain = self.compute_gain(self.get_cost(children), children)
                best_children = np.vstack((best_children,children[np.where(gain > 0)[0]]))

            
       
        return best_children

    
    def run(self, max_iter, max_sample, max_runtime, beta, turnover_rate, parent_to_children, random_selection, parent_changed, add_neighbours, radius):
        
        self.beta = beta
        self.turnover_rate = turnover_rate
        self.parent_to_children = parent_to_children
        self.random_selection = random_selection
        self.parent_changed = parent_changed
        self.add_neighbours = add_neighbours
        self.radius=radius
        self.neighbours= []
        for i in range(int(-self.N**2/2),int(self.N**2/2)):
                xx = np.sign(i)*i % self.N*np.sign(i)
                yy = int(i / self.N)
                mask = (xx)**2 + (yy)**2 < self.radius**2
                if not mask or i==0: continue
                self.neighbours.append(i)
                
        
        start_runtime = time.time()
        n_memory=0
        for _ in tqdm(range(max_iter)):
            if time.time() - start_runtime > max_runtime:
                break
            start_iter = time.time()
            self.non_zero_indices = self.active_indices[np.nonzero(self.current_gamma)]
            sample = 0
            #divide the non zero indices into chunks of size chunk_size
            best_children = self.find_best_child()
            while best_children.shape[0] < 2 and sample < max_sample:
                sample += 1
                best_children = self.find_best_child()
            if best_children.shape[0]<2:
                print("done?")
                break
            
            self.children_sampled.append(best_children.shape[0])
            self.n_children.append(self.active_indices.shape[0])
            self.current_cost_vector = np.append(self.current_cost_vector, self.get_cost(best_children))
            self.current_gamma = np.append(self.current_gamma, np.zeros(best_children.shape[0]))
            
            self.active_indices = np.vstack((self.active_indices, best_children))
            
            idx = best_children.copy().transpose()
            shift = np.array([i*self.N**self.dim for i in range(self.n_imgs)]).reshape(-1,1)
            idx = (idx+shift).transpose()
            reshaped_arr = idx.reshape(-1)

            # Create an array for the second element in each tuple
            second_elements = np.repeat(np.arange(len(best_children)), self.n_imgs)

            # Stack the two arrays
            stacked_arr = np.vstack((reshaped_arr, second_elements))
          
            A_children = sp.csr_matrix((np.ones(len(best_children)*self.n_imgs), (stacked_arr[0], stacked_arr[1])), shape=((self.N**self.dim)*self.n_imgs, len(best_children)))
            self.constraints_RMP = sp.hstack((self.constraints_RMP, A_children))
            n_memory+=1
                 
            self.time_child.append(time.time() - start_iter)
            
            if self.active_indices.shape[0] > int(self.beta*((self.N**self.dim)*self.n_imgs)):
                self.memory.append(n_memory)
                n_memory=0
                if self.beta>3:
                    remove_value = self.beta-1
                else:
                    remove_value = 1
                zero_indices = np.where(self.current_gamma == 0)[0][:int(remove_value*(self.N**self.dim)*self.n_imgs)]
                self.active_indices = np.delete(self.active_indices, zero_indices, axis=0)
                self.current_cost_vector = np.delete(self.current_cost_vector, zero_indices)
                self.current_gamma = np.delete(self.current_gamma, zero_indices)
                self.initialize_model()
                continue
            
            self.solve_model()
    
            



    def solve_model(self):
        start = time.time()
        self.m = gp.Model("model")
        self.gamma = self.m.addMVar(shape=len(self.current_cost_vector), vtype=GRB.CONTINUOUS, name="gamma")
        self.m.setObjective(self.current_cost_vector @ self.gamma, GRB.MINIMIZE)
        self.m.Params.OutputFlag = True
        self.m.Params.FeasibilityTol = 1e-8
        self.constraints = self.m.addConstr(self.constraints_RMP @ self.gamma == self.b_eq, name="eq_c")
        self.m.Params.LPWarmStart=2
        self.gamma.PStart = self.current_gamma
        self.constraints.DStart = self.current_kantorovich
        self.m.update
        self.m.optimize()
        primal_solution = np.array(self.gamma.X)
        dual_solution = np.array(self.m.PI)
        self.cost.append(self.m.ObjVal)
        self.time_model.append(time.time()-start)
        self.current_gamma = primal_solution
        self.current_kantorovich = dual_solution
        #print(dual_solution.shape)

    def get_mean(self, par):
        
        indices = np.array([[np.unravel_index(self.active_indices.transpose()[i], (self.N, self.N))[j] for i in range(self.n_imgs)] for j in range(2)]) 
        indices = indices.transpose((1,0,2))
        mean = [np.sum([par[i]*indices[i][j] for i in range(self.n_imgs)], axis=0).astype('int') for j in range(2)]        
        mean = np.ravel_multi_index(mean, (self.N, self.N))
        gamma = sp.csr_matrix((self.current_gamma, (self.active_indices.transpose()[0], mean)),
                              shape=(self.N ** 2, self.N ** 2))
        return 1-gamma.todense().transpose().dot(self.imgs[0]).reshape(self.N, self.N)

    def reduce(self):
        non_zero_indices = np.where(self.current_gamma != 0)[0]
        self.active_indices = self.active_indices[non_zero_indices]
        self.current_cost_vector = self.current_cost_vector[non_zero_indices]
        self.current_gamma = self.current_gamma[non_zero_indices]

    def plot(self):
        if self.n_imgs==2:
            plt.close()
            fig, axs = plt.subplots(2, 6)
            axs[0][0].imshow(self.get_mean((1,0)), cmap='gray')
            axs[0][1].imshow(self.get_mean((0.95,0.05)), cmap='gray')
            axs[0][2].imshow(self.get_mean((0.9,0.1)), cmap='gray')
            axs[0][3].imshow(self.get_mean((0.8,0.2)), cmap='gray')
            axs[0][4].imshow(self.get_mean((0.7,0.3)), cmap='gray')
            axs[0][5].imshow(self.get_mean((0.6,0.4)), cmap='gray')
            axs[1][0].imshow(self.get_mean((0.5,0.5)), cmap='gray')
            axs[1][1].imshow(self.get_mean((0.4,0.6)), cmap='gray')
            axs[1][2].imshow(self.get_mean((0.3,0.7)), cmap='gray')
            axs[1][3].imshow(self.get_mean((0.2,0.8)), cmap='gray')
            axs[1][4].imshow(self.get_mean((0.1,0.9)), cmap='gray')
            axs[1][5].imshow(self.get_mean((0,1)), cmap='gray')
            plt.show()
        if self.n_imgs==3:
            plt.close()
            fig, axs = plt.subplots(4, 4)
            axs[0][0].imshow(self.get_mean((1,0,0)), cmap='gray')
            axs[0][1].imshow(self.get_mean((0.67,0.33,0)), cmap='gray')
            axs[0][2].imshow(self.get_mean((0.37,0.63,0)), cmap='gray')
            axs[0][3].imshow(self.get_mean((0,1,0)), cmap='gray')
            axs[1][0].imshow(self.get_mean((0.67,0,0.33)), cmap='gray')
            axs[1][1].imshow(self.get_mean((0.5,0.25,0.25)), cmap='gray')
            axs[1][2].imshow(self.get_mean((0.25,0.5,0.25)), cmap='gray')
            axs[2][0].imshow(self.get_mean((0.33,0,0.67)), cmap='gray')
            axs[2][1].imshow(self.get_mean((0.25,0.25,0.5)), cmap='gray')
            axs[3][0].imshow(self.get_mean((0,0,1)), cmap='gray')  
            plt.show()
        if self.n_imgs>3:
            plt.close()
            fig, axs =plt.subplots(1,self.n_imgs+1)
            for i in range(self.n_imgs):
                axs[i].imshow(1-self.imgs[i].reshape(self.N,self.N), cmap='gray')
            axs[self.n_imgs].imshow(self.get_mean(tuple([1/self.n_imgs])*self.n_imgs), cmap='gray')
            plt.show()
            
    def save(self):
        matplotlib.image.imsave('barycenter.png', self.get_mean(0.5), cmap='Greys')

# %%
path_img1 = "dolphin_64.jpg"
path_img2 = "bird_64.jpg"
path_img3 = "star_64.jpg"
path_img4 = "flower_64.jpg"

dim=64 
n_imgs = 2
#copies: (32,(2,3,4,8,16,24)), (64,(2,3,4,8)), (128,(2,3,4)), 
#14 total tests (dim, n_imgs)

paths = [f"L/L{i}.jpg" for i in range(1,8)]
#paths = [path_img1,path_img2,path_img3]
img_list = [np.array(Image.open(path).convert('L')) for path in paths]
#img_list = [np.random.random((dim,dim)) for i in range(n_imgs)]
img_list = [1-img/255 for img in img_list]
img_list = [(img/np.sum(img))*img.shape[0] for img in img_list]

# %%
ga = Genetic_Algorithm(img_list)
# Out:
# initializing omega...
# omega initialized in 1.063. s
# initializing cost vector...
# cost vector initialized in 0.002. s
# initializing full model...
# 28384
# Set parameter FeasibilityTol to value 1e-08
# Set parameter LPWarmStart to value 2
# Warning on update mode = 1 after new variables or constraints added:
# Setting LP warm start basis or start ignored
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 28672 rows, 28384 columns and 198688 nonzeros
# Model fingerprint: 0x0fa752f5
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-05, 1e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e-04, 2e-01]
# Presolve removed 28672 rows and 28384 columns
# Presolve time: 0.02s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.5865320e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.03 seconds (0.03 work units)
# Optimal objective  1.586532049e+00
# full model initialized in 2.055. s

# %%
turnover_rate = 1 #0.001, 0.01, 0.1, 0.5 , 1 -->5
beta = 10 #1.1, 1.5,2, 2.5, 5 ---> 5
#beta*support + t_r*good_children = k
#we try beta = 3 - t_r/5?

#beta is the memory
#turnover rate is % of children we take
#if we increase turnover rate, we cannot have a too big memory (or it will slow down)
#but also it cannot be too little (or we will restart at every iteration)

parent_to_children = 1 #1, 0.1, 0.01, 0.001 --->4
#ration between parents and their children
#we select p_c*n_active_set parents and approximately 1/p_c children per parent

random_selection = False #true, false ---> 2
#if True, we don't take the top t_r children but just some random

parent_changed = 1 #--->1
#it has to be lower than n_imgs, it's the number of parents that will be randomized (become children)

add_neighbours = True
radius = 2


#idea: if the image are similar then neighbour is a good idea


#claim
#turnover_rate+beta is indipendent from p_c+random_selection+parent_changed

#1st test: dim+n_imgs+turnover_rate+beta = 14*5*5 tests for n min each
#2nd test: dim+n_imgs+p_c+random_selection = 14*4*2 tests for k iteration each

# %%
ga.run(max_iter=2000, max_sample=30, max_runtime=60, beta=beta, turnover_rate=turnover_rate, parent_to_children=parent_to_children, random_selection=random_selection, parent_changed=parent_changed, add_neighbours=add_neighbours, radius=radius)
# Out:
#   0%|                                                  | 0/2000 [00:00<?, ?it/s]
# Set parameter FeasibilityTol to value 1e-08
# Set parameter LPWarmStart to value 2
# Warning on update mode = 1 after new variables or constraints added:
# Setting LP warm start basis or start ignored
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 28672 rows, 33270 columns and 232890 nonzeros
# Model fingerprint: 0xb02f2797
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-05, 1e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e-04, 2e-01]
# Presolve removed 24994 rows and 28941 columns
# Presolve time: 0.03s
# Presolved: 3678 rows, 4329 columns, 29367 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 2.544e+04
#  Factor NZ  : 9.121e+04 (roughly 4 MB of memory)
#  Factor Ops : 2.946e+06 (less than 1 second per iteration)
#  Threads    : 6
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.43833042e+01  9.66116302e-01  3.42e+01 2.78e+00  5.90e-01     0s
#    1   2.96207756e+00  4.86675775e-01  3.67e+00 7.28e-14  8.17e-02     0s
#    2   1.77697538e+00  1.30983075e+00  5.10e-01 7.11e-14  1.32e-02     0s
#    3   1.60589499e+00  1.52249521e+00  5.19e-02 6.75e-14  2.25e-03     0s
#    4   1.59121080e+00  1.57090939e+00  1.26e-02 3.64e-14  5.21e-04     0s
#    5   1.58830133e+00  1.58139657e+00  4.82e-03 2.31e-14  1.68e-04     0s
#    6   1.58686441e+00  1.58303891e+00  9.50e-04 2.20e-14  1.06e-04     0s
#    7   1.58658417e+00  1.58619766e+00  1.96e-04 2.62e-14  9.74e-06     0s
#    8   1.58654901e+00  1.58639163e+00  1.04e-04 1.55e-14  3.73e-06     0s
#    9   1.58650921e+00  1.58648295e+00  2.22e-06 1.07e-14  7.56e-07     0s
#   10   1.58650788e+00  1.58650362e+00  1.23e-07 8.88e-15  1.25e-07     0s
#   11   1.58650766e+00  1.58650541e+00  2.31e-10 8.88e-15  6.63e-08     0s
#   12   1.58650760e+00  1.58650724e+00  4.22e-11 2.13e-14  1.05e-08     0s
#   13   1.58650759e+00  1.58650756e+00  4.01e-11 1.07e-14  1.04e-09     0s
#   14   1.58650759e+00  1.58650759e+00  3.61e-11 1.07e-14  6.83e-12     0s
#
# Barrier solved model in 14 iterations and 0.11 seconds (0.08 work units)
# Optimal objective 1.58650759e+00
#
# Crossover log...
#
#       45 DPushes remaining with DInf 0.0000000e+00                 0s
#        0 DPushes remaining with DInf 0.0000000e+00                 0s
#
#        1 PPushes remaining with PInf 0.0000000e+00                 0s
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 2.7075564e-12      0s
#
#
# Solved with barrier
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#       49    1.5865076e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 49 iterations and 0.15 seconds (0.11 work units)
# Optimal objective  1.586507591e+00
#   0%|                                          | 1/2000 [00:00<15:06,  2.20it/s]
# Set parameter FeasibilityTol to value 1e-08
# Set parameter LPWarmStart to value 2
# Warning on update mode = 1 after new variables or constraints added:
# Setting LP warm start basis or start ignored
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 28672 rows, 45337 columns and 317359 nonzeros
# Model fingerprint: 0x6ee3812e
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-05, 2e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e-04, 2e-01]
# Presolve removed 24642 rows and 38913 columns
# Presolve time: 0.04s
# Presolved: 4030 rows, 6424 columns, 44119 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 3.566e+04
#  Factor NZ  : 2.061e+05 (roughly 6 MB of memory)
#  Factor Ops : 2.052e+07 (less than 1 second per iteration)
#  Threads    : 6
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   2.75983224e+01 -5.92614030e-01  8.08e+01 3.15e+00  9.59e-01     0s
#    1   4.51601144e+00 -4.45480698e-01  9.11e+00 6.66e-14  1.30e-01     0s
#    2   2.10072920e+00  9.67005601e-01  1.60e+00 9.59e-14  2.56e-02     0s
#    3   1.66263734e+00  1.40252347e+00  2.38e-01 1.01e-13  5.40e-03     0s
#    4   1.60793987e+00  1.52028546e+00  6.75e-02 4.97e-14  1.74e-03     0s
#    5   1.59318542e+00  1.55012634e+00  2.14e-02 4.97e-14  8.41e-04     0s
#    6   1.58880093e+00  1.56929383e+00  7.57e-03 5.06e-14  3.77e-04     0s
#    7   1.58730376e+00  1.58192618e+00  2.86e-03 2.26e-14  1.00e-04     0s
#    8   1.58655100e+00  1.58530643e+00  5.18e-04 1.95e-14  2.32e-05     0s
#    9   1.58643855e+00  1.58600770e+00  2.15e-04 1.82e-14  7.76e-06     0s
#   10   1.58642765e+00  1.58612303e+00  1.89e-04 1.77e-14  5.29e-06     0s
#   11   1.58640252e+00  1.58616700e+00  1.31e-04 1.42e-14  4.14e-06     0s
#   12   1.58634769e+00  1.58626054e+00  1.42e-05 1.42e-14  1.67e-06     0s
#   13   1.58633994e+00  1.58629219e+00  6.48e-06 1.78e-14  9.21e-07     0s
#   14   1.58633392e+00  1.58631600e+00  5.45e-07 1.33e-14  3.54e-07     0s
#   15   1.58633275e+00  1.58632654e+00  6.44e-08 1.07e-14  1.23e-07     0s
#   16   1.58633236e+00  1.58633128e+00  1.90e-09 2.13e-14  2.14e-08     0s
#   17   1.58633231e+00  1.58633213e+00  4.09e-10 1.69e-14  3.60e-09     0s
#   18   1.58633229e+00  1.58633228e+00  6.04e-11 1.95e-14  1.50e-10     0s
#
# Barrier solved model in 18 iterations and 0.17 seconds (0.14 work units)
# Optimal objective 1.58633229e+00
#
# Crossover log...
#
#        5 DPushes remaining with DInf 0.0000000e+00                 0s
#        0 DPushes remaining with DInf 0.0000000e+00                 0s
#
#      105 PPushes remaining with PInf 0.0000000e+00                 0s
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 4.3804960e-12      0s
#
#
# Solved with barrier
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      113    1.5863323e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 113 iterations and 0.21 seconds (0.17 work units)
# Optimal objective  1.586332285e+00
#   0%|                                          | 2/2000 [00:00<13:57,  2.39it/s]
# Set parameter FeasibilityTol to value 1e-08
# Set parameter LPWarmStart to value 2
# Warning on update mode = 1 after new variables or constraints added:
# Setting LP warm start basis or start ignored
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 28672 rows, 50235 columns and 351645 nonzeros
# Model fingerprint: 0x1c0d87d7
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-05, 2e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e-04, 2e-01]
# Presolve removed 24524 rows and 42854 columns
# Presolve time: 0.04s
# Presolved: 4148 rows, 7381 columns, 51162 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.06s
#
# Barrier statistics:
#  AA' NZ     : 4.023e+04
#  Factor NZ  : 2.535e+05 (roughly 7 MB of memory)
#  Factor Ops : 3.005e+07 (less than 1 second per iteration)
#  Threads    : 6
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   2.68173009e+01 -4.28281803e-01  7.37e+01 3.06e+00  7.83e-01     0s
#    1   4.47085832e+00 -2.37988873e-01  8.43e+00 4.62e-14  1.06e-01     0s
#    2   2.20426443e+00  1.03156489e+00  1.81e+00 5.95e-14  2.35e-02     0s
#    3   1.70306213e+00  1.41492846e+00  3.43e-01 4.63e-14  5.35e-03     0s
#    4   1.62109313e+00  1.51548439e+00  1.03e-01 4.44e-14  1.86e-03     0s
#    5   1.60151405e+00  1.55244085e+00  4.53e-02 2.66e-14  8.33e-04     0s
#    6   1.59154466e+00  1.57382829e+00  1.59e-02 2.66e-14  2.89e-04     0s
#    7   1.58765451e+00  1.58264765e+00  4.30e-03 2.49e-14  7.90e-05     0s
#    8   1.58646753e+00  1.58521878e+00  7.76e-04 2.98e-14  1.98e-05     0s
#    9   1.58620568e+00  1.58571355e+00  1.54e-04 2.09e-14  8.08e-06     0s
#   10   1.58616120e+00  1.58588123e+00  8.74e-05 1.78e-14  4.56e-06     0s
#   11   1.58613573e+00  1.58597821e+00  5.46e-05 1.42e-14  2.53e-06     0s
#   12   1.58610462e+00  1.58603181e+00  1.81e-05 1.50e-14  1.19e-06     0s
#   13   1.58608957e+00  1.58606819e+00  4.02e-06 1.51e-14  3.55e-07     0s
#   14   1.58608517e+00  1.58607870e+00  1.03e-06 1.78e-14  1.08e-07     0s
#   15   1.58608373e+00  1.58608177e+00  1.93e-07 1.42e-14  3.32e-08     0s
#   16   1.58608342e+00  1.58608288e+00  3.66e-08 1.78e-14  9.11e-09     0s
#   17   1.58608335e+00  1.58608326e+00  4.39e-09 2.13e-14  1.45e-09     0s
#   18   1.58608334e+00  1.58608333e+00  1.90e-10 1.78e-14  1.63e-11     0s
#
# Barrier solved model in 18 iterations and 0.21 seconds (0.17 work units)
# Optimal objective 1.58608334e+00
#
# Crossover log...
#
#       77 DPushes remaining with DInf 0.0000000e+00                 0s
#        0 DPushes remaining with DInf 0.0000000e+00                 0s
#
#       11 PPushes remaining with PInf 0.0000000e+00                 0s
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 6.1263217e-12      0s
#
#
# Solved with barrier
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#       91    1.5860833e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 91 iterations and 0.26 seconds (0.22 work units)
# Optimal objective  1.586083335e+00
#   0%|                                          | 3/2000 [00:01<15:33,  2.14it/s]
# Set parameter FeasibilityTol to value 1e-08
# Set parameter LPWarmStart to value 2
# Warning on update mode = 1 after new variables or constraints added:
# Setting LP warm start basis or start ignored
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 28672 rows, 59931 columns and 419517 nonzeros
# Model fingerprint: 0x8cef9376
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-05, 2e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e-04, 2e-01]
# Presolve removed 24233 rows and 50229 columns
# Presolve time: 0.05s
# Presolved: 4439 rows, 9702 columns, 67396 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.07s
#
# Barrier statistics:
#  AA' NZ     : 5.069e+04
#  Factor NZ  : 4.320e+05 (roughly 10 MB of memory)
#  Factor Ops : 7.932e+07 (less than 1 second per iteration)
#  Threads    : 6
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   3.80380757e+01 -3.70575481e+00  8.35e+01 8.09e+00  1.35e+00     0s
#    1   6.64062802e+00 -2.14964687e+00  1.16e+01 5.51e-14  2.08e-01     0s
#    2   2.62256293e+00  5.05983555e-01  2.38e+00 8.70e-14  4.34e-02     0s
#    3   1.76333813e+00  1.20018911e+00  4.08e-01 1.28e-13  9.90e-03     0s
#    4   1.63277413e+00  1.46086971e+00  1.08e-01 5.15e-14  2.81e-03     0s
#    5   1.60192955e+00  1.52672314e+00  3.69e-02 6.93e-14  1.15e-03     0s
#    6   1.59078206e+00  1.56754113e+00  1.09e-02 4.71e-14  3.42e-04     0s
#    7   1.58700857e+00  1.57871979e+00  2.01e-03 5.73e-14  1.14e-04     0s
#    8   1.58632610e+00  1.58336323e+00  4.81e-04 3.20e-14  3.93e-05     0s
#    9   1.58612252e+00  1.58453466e+00  2.29e-04 3.55e-14  2.09e-05     0s
#   10   1.58601439e+00  1.58515901e+00  1.22e-04 3.38e-14  1.11e-05     0s
#   11   1.58593069e+00  1.58547260e+00  4.80e-05 2.31e-14  5.97e-06     0s
#   12   1.58588307e+00  1.58571704e+00  1.68e-05 2.22e-14  2.16e-06     0s
#   13   1.58586519e+00  1.58577934e+00  7.61e-06 2.22e-14  1.12e-06     0s
#   14   1.58585570e+00  1.58579648e+00  3.24e-06 1.95e-14  7.74e-07     0s
#   15   1.58585096e+00  1.58581148e+00  1.34e-06 2.66e-14  5.18e-07     0s
#   16   1.58584767e+00  1.58583053e+00  2.94e-07 2.07e-14  2.25e-07     0s
#   17   1.58584625e+00  1.58584383e+00  2.98e-09 2.49e-14  3.19e-08     0s
#   18   1.58584614e+00  1.58584541e+00  3.59e-10 2.93e-14  9.51e-09     0s
#   19   1.58584611e+00  1.58584578e+00  8.71e-11 2.22e-14  4.39e-09     0s
#   20   1.58584610e+00  1.58584609e+00  2.05e-11 2.13e-14  1.17e-10     0s
#
# Barrier solved model in 20 iterations and 0.30 seconds (0.26 work units)
# Optimal objective 1.58584610e+00
#
# Crossover log...
#
#        8 DPushes remaining with DInf 0.0000000e+00                 0s
#        0 DPushes remaining with DInf 0.0000000e+00                 0s
#
#       63 PPushes remaining with PInf 0.0000000e+00                 0s
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.0623835e-11      0s
#
#
# Solved with barrier
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#       74    1.5858461e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 74 iterations and 0.35 seconds (0.30 work units)
# Optimal objective  1.585846101e+00
#   0%|                                          | 4/2000 [00:01<16:48,  1.98it/s]
# Set parameter FeasibilityTol to value 1e-08
# Set parameter LPWarmStart to value 2
# Warning on update mode = 1 after new variables or constraints added:
# Setting LP warm start basis or start ignored
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 28672 rows, 65048 columns and 455336 nonzeros
# Model fingerprint: 0x1d27b177
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-05, 2e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e-04, 2e-01]
# Presolve removed 24055 rows and 54066 columns
# Presolve time: 0.06s
# Presolved: 4617 rows, 10982 columns, 76850 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.12s
#
# Barrier statistics:
#  AA' NZ     : 5.853e+04
#  Factor NZ  : 6.522e+05 (roughly 12 MB of memory)
#  Factor Ops : 1.710e+08 (less than 1 second per iteration)
#  Threads    : 6
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   4.72261449e+01 -4.28679791e+00  9.74e+01 8.41e+00  1.49e+00     0s
#    1   7.26577043e+00 -2.67585213e+00  1.21e+01 5.48e-14  2.10e-01     0s
#    2   2.78392252e+00  3.71432942e-01  2.56e+00 6.48e-14  4.48e-02     0s
#    3   1.83589187e+00  1.07932189e+00  5.36e-01 6.66e-14  1.21e-02     0s
#    4   1.62586924e+00  1.45073178e+00  8.68e-02 4.88e-14  2.51e-03     0s
#    5   1.59664393e+00  1.55057240e+00  2.34e-02 4.09e-14  6.39e-04     0s
#    6   1.59004217e+00  1.57065905e+00  8.98e-03 2.90e-14  2.57e-04     0s
#    7   1.58763632e+00  1.57794362e+00  3.75e-03 3.20e-14  1.22e-04     0s
#    8   1.58654249e+00  1.58207976e+00  1.51e-03 3.02e-14  5.35e-05     0s
#    9   1.58612525e+00  1.58316859e+00  7.69e-04 2.75e-14  3.47e-05     0s
#   10   1.58599412e+00  1.58407181e+00  5.72e-04 2.66e-14  2.23e-05     0s
#   11   1.58569060e+00  1.58450188e+00  1.80e-04 3.20e-14  1.38e-05     0s
#   12   1.58557018e+00  1.58506293e+00  8.48e-05 2.40e-14  5.81e-06     0s
#   13   1.58551078e+00  1.58524644e+00  4.76e-05 2.31e-14  3.01e-06     0s
#   14   1.58547871e+00  1.58531860e+00  2.89e-05 1.78e-14  1.82e-06     0s
#   15   1.58544963e+00  1.58537189e+00  1.29e-05 2.66e-14  8.85e-07     0s
#   16   1.58542934e+00  1.58540331e+00  2.69e-06 2.13e-14  2.99e-07     0s
#   17   1.58542408e+00  1.58541581e+00  5.79e-07 2.49e-14  9.54e-08     0s
#   18   1.58542287e+00  1.58542007e+00  1.74e-07 2.04e-14  3.23e-08     0s
#   19   1.58542253e+00  1.58542194e+00  7.80e-08 2.66e-14  6.70e-09     0s
#   20   1.58542226e+00  1.58542220e+00  4.24e-09 1.69e-14  6.17e-10     0s
#   21   1.58542224e+00  1.58542224e+00  1.54e-11 2.49e-14  5.93e-12     0s
#
# Barrier solved model in 21 iterations and 0.45 seconds (0.35 work units)
# Optimal objective 1.58542224e+00
#
# Crossover log...
#
#       26 DPushes remaining with DInf 0.0000000e+00                 0s
#        0 DPushes remaining with DInf 0.0000000e+00                 0s
#
#       11 PPushes remaining with PInf 0.0000000e+00                 0s
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.2266410e-11      0s
#
#
# Solved with barrier
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#       40    1.5854222e+00   0.000000e+00   0.000000e+00      1s
#
# Solved in 40 iterations and 0.51 seconds (0.40 work units)
# Optimal objective  1.585422238e+00
#   0%|                                          | 5/2000 [00:02<20:33,  1.62it/s]
# Set parameter FeasibilityTol to value 1e-08
# Set parameter LPWarmStart to value 2
# Warning on update mode = 1 after new variables or constraints added:
# Setting LP warm start basis or start ignored
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 28672 rows, 67628 columns and 473396 nonzeros
# Model fingerprint: 0xcbddb537
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-05, 2e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e-04, 2e-01]
# Presolve removed 23999 rows and 55988 columns
# Presolve time: 0.06s
# Presolved: 4673 rows, 11640 columns, 81438 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.10s
#
# Barrier statistics:
#  AA' NZ     : 6.196e+04
#  Factor NZ  : 7.084e+05 (roughly 12 MB of memory)
#  Factor Ops : 1.979e+08 (less than 1 second per iteration)
#  Threads    : 6
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   5.49709026e+01 -4.08165178e+00  1.20e+02 8.38e+00  1.62e+00     0s
#    1   8.83664905e+00 -2.88668008e+00  1.63e+01 7.28e-14  2.44e-01     0s
#    2   2.85345535e+00  3.32312908e-01  2.86e+00 4.97e-14  4.47e-02     0s
#    3   1.80607152e+00  1.12891430e+00  4.99e-01 6.62e-14  1.02e-02     0s
#    4   1.62767172e+00  1.44896603e+00  9.61e-02 6.57e-14  2.46e-03     0s
#    5   1.59683256e+00  1.53940099e+00  2.54e-02 6.93e-14  7.39e-04     0s
#    6   1.59051402e+00  1.56802339e+00  1.08e-02 5.15e-14  2.83e-04     0s
#    7   1.58745906e+00  1.57651061e+00  3.90e-03 4.62e-14  1.29e-04     0s
#    8   1.58629930e+00  1.58038302e+00  1.49e-03 3.64e-14  6.69e-05     0s
#    9   1.58601233e+00  1.58216694e+00  1.00e-03 4.26e-14  4.29e-05     0s
#   10   1.58568078e+00  1.58356284e+00  4.42e-04 3.38e-14  2.32e-05     0s
#   11   1.58548410e+00  1.58440878e+00  2.28e-04 3.02e-14  1.17e-05     0s
#   12   1.58537111e+00  1.58478324e+00  1.25e-04 3.55e-14  6.34e-06     0s
#   13   1.58530319e+00  1.58495369e+00  7.15e-05 2.84e-14  3.76e-06     0s
#   14   1.58524807e+00  1.58507759e+00  3.18e-05 4.62e-14  1.83e-06     0s
#   15   1.58520998e+00  1.58515498e+00  6.88e-06 3.91e-14  5.95e-07     0s
#   16   1.58519986e+00  1.58517961e+00  1.67e-06 3.02e-14  2.20e-07     0s
#   17   1.58519732e+00  1.58519041e+00  5.06e-07 2.84e-14  7.52e-08     0s
#   18   1.58519610e+00  1.58519467e+00  8.85e-08 3.46e-14  1.55e-08     0s
#   19   1.58519578e+00  1.58519563e+00  4.12e-10 3.02e-14  1.67e-09     0s
#   20   1.58519577e+00  1.58519576e+00  4.92e-11 4.26e-14  9.19e-11     0s
#
# Barrier solved model in 20 iterations and 0.42 seconds (0.37 work units)
# Optimal objective 1.58519577e+00
#
# Crossover log...
#
#        4 DPushes remaining with DInf 0.0000000e+00                 0s
#        0 DPushes remaining with DInf 0.0000000e+00                 0s
#
#       24 PPushes remaining with PInf 0.0000000e+00                 0s
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.1034118e-11      0s
#
#
# Solved with barrier
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#       31    1.5851958e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 31 iterations and 0.47 seconds (0.42 work units)
# Optimal objective  1.585195767e+00
#   0%|▏                                         | 6/2000 [00:03<21:22,  1.55it/s]
# Set parameter FeasibilityTol to value 1e-08
# Set parameter LPWarmStart to value 2
# Warning on update mode = 1 after new variables or constraints added:
# Setting LP warm start basis or start ignored
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 28672 rows, 70930 columns and 496510 nonzeros
# Model fingerprint: 0x09b871ad
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-05, 2e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e-04, 2e-01]
# Presolve removed 23937 rows and 58809 columns
# Presolve time: 0.06s
# Presolved: 4735 rows, 12121 columns, 84421 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.10s
#
# Barrier statistics:
#  AA' NZ     : 6.421e+04
#  Factor NZ  : 7.623e+05 (roughly 13 MB of memory)
#  Factor Ops : 2.255e+08 (less than 1 second per iteration)
#  Threads    : 6
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   4.86629397e+01 -4.03621237e+00  1.06e+02 8.39e+00  1.39e+00     0s
#    1   7.40649003e+00 -2.53256316e+00  1.30e+01 4.44e-14  1.94e-01     0s
#    2   2.67595601e+00  3.32101629e-01  2.45e+00 4.09e-14  3.89e-02     0s
#    3   1.79372765e+00  1.05954510e+00  4.70e-01 4.97e-14  1.04e-02     0s
#    4   1.62735604e+00  1.42370005e+00  9.59e-02 6.04e-14  2.63e-03     0s
#    5   1.59495071e+00  1.53002026e+00  2.18e-02 6.57e-14  7.79e-04     0s
#    6   1.59009986e+00  1.55570678e+00  1.05e-02 6.04e-14  4.00e-04     0s
#    7   1.58707371e+00  1.56879083e+00  3.61e-03 5.02e-14  2.03e-04     0s
#    8   1.58614712e+00  1.57573926e+00  1.68e-03 5.82e-14  1.13e-04     0s
#    9   1.58574962e+00  1.57936766e+00  9.66e-04 4.09e-14  6.83e-05     0s
#   10   1.58532888e+00  1.58196473e+00  3.94e-04 4.09e-14  3.56e-05     0s
#   11   1.58507022e+00  1.58383718e+00  1.45e-04 3.20e-14  1.29e-05     0s
#   12   1.58495255e+00  1.58422662e+00  6.80e-05 2.84e-14  7.61e-06     0s
#   13   1.58488934e+00  1.58450002e+00  3.64e-05 3.20e-14  4.07e-06     0s
#   14   1.58483960e+00  1.58466379e+00  1.32e-05 3.55e-14  1.84e-06     0s
#   15   1.58481593e+00  1.58476578e+00  4.12e-06 3.20e-14  5.24e-07     0s
#   16   1.58480600e+00  1.58478948e+00  9.43e-07 2.93e-14  1.73e-07     0s
#   17   1.58480394e+00  1.58479654e+00  3.74e-07 3.20e-14  7.76e-08     0s
#   18   1.58480264e+00  1.58480198e+00  3.89e-08 3.91e-14  6.85e-09     0s
#   19   1.58480240e+00  1.58480237e+00  2.94e-09 3.55e-14  2.95e-10     0s
#   20   1.58480240e+00  1.58480237e+00  4.96e-09 3.91e-14  2.94e-10     0s
#   21   1.58480242e+00  1.58480237e+00  5.86e-08 4.64e-14  2.23e-10     0s
#   22   1.58480241e+00  1.58480237e+00  5.44e-08 3.02e-14  1.66e-10     1s
#   23   1.58480240e+00  1.58480237e+00  2.59e-08 2.66e-14  7.92e-11     1s
#
# Barrier solved model in 23 iterations and 0.53 seconds (0.47 work units)
# Optimal objective 1.58480240e+00
#
# Crossover log...
#
#       24 DPushes remaining with DInf 0.0000000e+00                 1s
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#      168 PPushes remaining with PInf 5.5262242e-07                 1s
#        0 PPushes remaining with PInf 7.8657936e-07                 1s
#
#   Push phase complete: Pinf 7.8657936e-07, Dinf 1.1834200e-11      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      195    1.5848024e+00   7.865794e-07   0.000000e+00      1s
#
# Solved with barrier
#      196    1.5848024e+00   0.000000e+00   0.000000e+00      1s
#
# Solved in 196 iterations and 0.60 seconds (0.55 work units)
# Optimal objective  1.584802371e+00
#   0%|▏                                         | 7/2000 [00:04<24:14,  1.37it/s]
# Set parameter FeasibilityTol to value 1e-08
# Set parameter LPWarmStart to value 2
# Warning on update mode = 1 after new variables or constraints added:
# Setting LP warm start basis or start ignored
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 28672 rows, 73969 columns and 517783 nonzeros
# Model fingerprint: 0x8a560041
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-05, 2e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e-04, 2e-01]
# Presolve removed 23904 rows and 61359 columns
# Presolve time: 0.07s
# Presolved: 4768 rows, 12610 columns, 88339 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.13s
#
# Barrier statistics:
#  AA' NZ     : 6.734e+04
#  Factor NZ  : 8.515e+05 (roughly 14 MB of memory)
#  Factor Ops : 2.789e+08 (less than 1 second per iteration)
#  Threads    : 6
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   5.10755351e+01 -4.43716457e+00  1.09e+02 8.63e+00  1.45e+00     0s
#    1   7.70148107e+00 -2.77317566e+00  1.35e+01 2.62e-14  2.01e-01     0s
#    2   2.80195942e+00  3.34132840e-01  2.69e+00 4.31e-14  4.15e-02     0s
#    3   1.81140124e+00  1.08023264e+00  5.03e-01 4.17e-14  1.04e-02     0s
#    4   1.62832134e+00  1.41638869e+00  9.73e-02 3.91e-14  2.68e-03     0s
#    5   1.59448670e+00  1.52787460e+00  2.15e-02 5.17e-14  7.69e-04     0s
#    6   1.58906341e+00  1.55841797e+00  9.47e-03 5.51e-14  3.41e-04     0s
#    7   1.58680965e+00  1.56934489e+00  4.61e-03 4.01e-14  1.87e-04     0s
#    8   1.58589725e+00  1.57357185e+00  2.90e-03 4.71e-14  1.30e-04     0s
#    9   1.58533989e+00  1.57441310e+00  1.89e-03 5.51e-14  1.14e-04     0s
#   10   1.58502696e+00  1.58060614e+00  1.41e-03 4.17e-14  4.51e-05     0s
#   11   1.58432440e+00  1.58201060e+00  4.68e-04 4.14e-14  2.34e-05     0s
#   12   1.58408922e+00  1.58253970e+00  2.73e-04 6.48e-14  1.56e-05     0s
#   13   1.58396993e+00  1.58307008e+00  1.76e-04 4.44e-14  8.97e-06     0s
#   14   1.58382335e+00  1.58336462e+00  7.12e-05 3.82e-14  4.57e-06     0s
#   15   1.58375599e+00  1.58347456e+00  3.15e-05 3.64e-14  2.81e-06     0s
#   16   1.58372816e+00  1.58357328e+00  1.76e-05 3.64e-14  1.55e-06     0s
#   17   1.58370636e+00  1.58361568e+00  7.57e-06 4.40e-14  9.09e-07     0s
#   18   1.58369479e+00  1.58366468e+00  2.66e-06 5.24e-14  3.01e-07     1s
#   19   1.58368888e+00  1.58367878e+00  5.67e-07 3.46e-14  1.02e-07     1s
#   20   1.58368731e+00  1.58368526e+00  8.08e-08 4.80e-14  2.06e-08     1s
#   21   1.58368694e+00  1.58368650e+00  2.32e-09 3.66e-14  4.45e-09     1s
#   22   1.58368693e+00  1.58368684e+00  1.42e-09 4.00e-14  8.47e-10     1s
#   23   1.58368691e+00  1.58368687e+00  3.07e-10 3.55e-14  4.50e-10     1s
#   24   1.58368691e+00  1.58368691e+00  7.39e-11 4.91e-14  2.54e-11     1s
#
# Barrier solved model in 24 iterations and 0.58 seconds (0.49 work units)
# Optimal objective 1.58368691e+00
#
# Crossover log...
#
#      223 DPushes remaining with DInf 0.0000000e+00                 1s
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#       16 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 2.4666269e-11      1s
#
#
# Solved with barrier
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      242    1.5836869e+00   0.000000e+00   0.000000e+00      1s
#
# Solved in 242 iterations and 0.66 seconds (0.59 work units)
# Optimal objective  1.583686912e+00
#   0%|▏                                         | 8/2000 [00:05<26:53,  1.23it/s]
# Set parameter FeasibilityTol to value 1e-08
# Set parameter LPWarmStart to value 2
# Warning on update mode = 1 after new variables or constraints added:
# Setting LP warm start basis or start ignored
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 28672 rows, 80845 columns and 565915 nonzeros
# Model fingerprint: 0xc795f3a7
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-05, 2e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e-04, 2e-01]
# Presolve removed 23832 rows and 67361 columns
# Presolve time: 0.07s
# Presolved: 4840 rows, 13484 columns, 93872 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.13s
#
# Barrier statistics:
#  AA' NZ     : 7.144e+04
#  Factor NZ  : 9.383e+05 (roughly 15 MB of memory)
#  Factor Ops : 3.282e+08 (less than 1 second per iteration)
#  Threads    : 6
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   6.19138946e+01 -5.84414847e+00  9.91e+01 8.72e+00  1.70e+00     0s
#    1   9.93713442e+00 -3.68876241e+00  1.37e+01 2.55e-14  2.59e-01     0s
#    2   3.14850431e+00 -1.04334462e-01  2.57e+00 2.94e-14  5.15e-02     0s
#    3   1.90864370e+00  9.75408996e-01  5.33e-01 3.02e-14  1.31e-02     0s
#    4   1.65524940e+00  1.34918851e+00  1.17e-01 3.66e-14  3.76e-03     0s
#    5   1.60690312e+00  1.49533039e+00  3.72e-02 3.91e-14  1.28e-03     0s
#    6   1.59285572e+00  1.53840669e+00  1.38e-02 3.38e-14  5.80e-04     0s
#    7   1.58842133e+00  1.56053389e+00  6.55e-03 3.73e-14  2.85e-04     0s
#    8   1.58628319e+00  1.57144575e+00  3.40e-03 3.90e-14  1.47e-04     0s
#    9   1.58507266e+00  1.57722040e+00  1.84e-03 2.84e-14  7.54e-05     0s
#   10   1.58416445e+00  1.58040807e+00  9.16e-04 2.66e-14  3.52e-05     0s
#   11   1.58350927e+00  1.58175665e+00  3.64e-04 2.13e-14  1.62e-05     0s
#   12   1.58331039e+00  1.58219444e+00  2.27e-04 3.29e-14  1.03e-05     0s
#   13   1.58315719e+00  1.58247291e+00  1.30e-04 2.36e-14  6.27e-06     0s
#   14   1.58308541e+00  1.58266438e+00  8.81e-05 3.38e-14  3.83e-06     0s
#   15   1.58299138e+00  1.58277265e+00  3.71e-05 3.38e-14  2.00e-06     0s
#   16   1.58294052e+00  1.58284541e+00  1.20e-05 4.80e-14  8.78e-07     0s
#   17   1.58291841e+00  1.58288893e+00  2.48e-06 2.40e-14  2.75e-07     0s
#   18   1.58291421e+00  1.58290081e+00  9.28e-07 2.25e-14  1.25e-07     1s
#   19   1.58291257e+00  1.58290738e+00  3.83e-07 3.20e-14  4.84e-08     1s
#   20   1.58291165e+00  1.58291022e+00  9.73e-08 2.13e-14  1.34e-08     1s
#   21   1.58291137e+00  1.58291094e+00  1.76e-08 2.40e-14  4.01e-09     1s
#   22   1.58291129e+00  1.58291126e+00  1.80e-10 3.11e-14  3.02e-10     1s
#   23   1.58291129e+00  1.58291129e+00  1.44e-10 3.02e-14  2.99e-12     1s
#
# Barrier solved model in 23 iterations and 0.58 seconds (0.53 work units)
# Optimal objective 1.58291129e+00
#
# Crossover log...
#
#       34 DPushes remaining with DInf 0.0000000e+00                 1s
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#       12 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 2.0186519e-11      1s
#
#
# Solved with barrier
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#       49    1.5829113e+00   0.000000e+00   0.000000e+00      1s
#
# Solved in 49 iterations and 0.64 seconds (0.58 work units)
# Optimal objective  1.582911289e+00
#   0%|▏                                         | 9/2000 [00:06<27:45,  1.20it/s]
# Set parameter FeasibilityTol to value 1e-08
# Set parameter LPWarmStart to value 2
# Warning on update mode = 1 after new variables or constraints added:
# Setting LP warm start basis or start ignored
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 28672 rows, 82877 columns and 580139 nonzeros
# Model fingerprint: 0xd69e9f35
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-05, 2e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e-04, 2e-01]
# Presolve removed 23784 rows and 68952 columns
# Presolve time: 0.07s
# Presolved: 4888 rows, 13925 columns, 96156 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.14s
#
# Barrier statistics:
#  AA' NZ     : 7.282e+04
#  Factor NZ  : 9.661e+05 (roughly 15 MB of memory)
#  Factor Ops : 3.385e+08 (less than 1 second per iteration)
#  Threads    : 6
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   5.86730120e+01 -6.29638178e+00  8.18e+01 8.81e+00  1.59e+00     0s
#    1   9.73643276e+00 -3.68156132e+00  1.17e+01 2.31e-14  2.49e-01     0s
#    2   3.01604979e+00  1.09603680e-01  2.05e+00 3.20e-14  4.59e-02     0s
#    3   1.90133776e+00  1.04246517e+00  4.55e-01 4.09e-14  1.20e-02     0s
#    4   1.64927877e+00  1.38106274e+00  9.38e-02 4.97e-14  3.25e-03     0s
#    5   1.59925290e+00  1.50560501e+00  2.15e-02 4.09e-14  1.01e-03     0s
#    6   1.59032169e+00  1.54437138e+00  8.57e-03 4.80e-14  4.67e-04     0s
#    7   1.58694986e+00  1.55874781e+00  3.91e-03 3.91e-14  2.74e-04     0s
#    8   1.58581263e+00  1.56983132e+00  2.45e-03 4.26e-14  1.52e-04     0s
#    9   1.58467033e+00  1.57512793e+00  1.33e-03 4.44e-14  8.85e-05     0s
#   10   1.58355893e+00  1.57970810e+00  4.62e-04 3.38e-14  3.51e-05     0s
#   11   1.58310246e+00  1.58083727e+00  2.21e-04 3.20e-14  2.05e-05     0s
#   12   1.58285203e+00  1.58167254e+00  1.22e-04 2.66e-14  1.06e-05     0s
#   13   1.58268144e+00  1.58201428e+00  5.71e-05 3.20e-14  6.01e-06     0s
#   14   1.58255983e+00  1.58226721e+00  1.86e-05 3.91e-14  2.65e-06     0s
#   15   1.58250971e+00  1.58243527e+00  4.86e-06 3.20e-14  6.72e-07     0s
#   16   1.58249219e+00  1.58246530e+00  1.23e-06 2.66e-14  2.44e-07     0s
#   17   1.58248753e+00  1.58248008e+00  4.24e-07 4.26e-14  6.74e-08     1s
#   18   1.58248635e+00  1.58248207e+00  2.38e-07 3.20e-14  3.87e-08     1s
#   19   1.58248534e+00  1.58248380e+00  7.91e-08 2.66e-14  1.40e-08     1s
#   20   1.58248498e+00  1.58248455e+00  2.60e-08 3.38e-14  3.86e-09     1s
#   21   1.58248480e+00  1.58248477e+00  1.04e-09 3.20e-14  2.42e-10     1s
#   22   1.58248479e+00  1.58248479e+00  1.08e-10 3.20e-14  1.34e-12     1s
#
# Barrier solved model in 22 iterations and 0.57 seconds (0.54 work units)
# Optimal objective 1.58248479e+00
#
# Crossover log...
#
#       10 DPushes remaining with DInf 0.0000000e+00                 1s
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#       13 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 9.9696223e-12      1s
#
#
# Solved with barrier
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#       26    1.5824848e+00   0.000000e+00   0.000000e+00      1s
#
# Solved in 26 iterations and 0.64 seconds (0.59 work units)
# Optimal objective  1.582484787e+00
#   0%|▏                                        | 10/2000 [00:07<29:06,  1.14it/s]
# Set parameter FeasibilityTol to value 1e-08
# Set parameter LPWarmStart to value 2
# Warning on update mode = 1 after new variables or constraints added:
# Setting LP warm start basis or start ignored
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 28672 rows, 85314 columns and 597198 nonzeros
# Model fingerprint: 0xac4058e9
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-05, 2e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e-04, 2e-01]
# Presolve removed 23749 rows and 70954 columns
# Presolve time: 0.08s
# Presolved: 4923 rows, 14360 columns, 100783 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.14s
#
# Barrier statistics:
#  AA' NZ     : 7.588e+04
#  Factor NZ  : 1.024e+06 (roughly 16 MB of memory)
#  Factor Ops : 3.814e+08 (less than 1 second per iteration)
#  Threads    : 6
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   6.17156703e+01 -6.93352597e+00  1.28e+02 8.81e+00  1.65e+00     0s
#    1   1.00095197e+01 -4.00778326e+00  1.79e+01 2.31e-14  2.55e-01     0s
#    2   3.00742924e+00  1.90507342e-02  3.03e+00 3.20e-14  4.57e-02     0s
#    3   1.88872281e+00  1.01537110e+00  6.50e-01 3.02e-14  1.18e-02     0s
#    4   1.69437008e+00  1.26321629e+00  2.37e-01 2.66e-14  5.18e-03     0s
#    5   1.61742217e+00  1.44599034e+00  7.25e-02 5.15e-14  1.89e-03     0s
#    6   1.59054630e+00  1.52182064e+00  1.49e-02 5.68e-14  6.69e-04     0s
#    7   1.58530541e+00  1.55927266e+00  4.34e-03 4.97e-14  2.42e-04     0s
#    8   1.58355983e+00  1.57331609e+00  1.91e-03 5.15e-14  9.25e-05     0s
#    9   1.58281666e+00  1.57599293e+00  1.02e-03 4.97e-14  6.09e-05     0s
#   10   1.58231245e+00  1.57838218e+00  6.03e-04 3.91e-14  3.47e-05     0s
#   11   1.58190678e+00  1.57978188e+00  3.38e-04 3.38e-14  1.86e-05     0s
#   12   1.58165852e+00  1.58040203e+00  1.96e-04 3.02e-14  1.10e-05     0s
#   13   1.58147529e+00  1.58069986e+00  9.93e-05 4.26e-14  6.77e-06     0s
#   14   1.58137533e+00  1.58099915e+00  5.20e-05 3.20e-14  3.27e-06     0s
#   15   1.58129373e+00  1.58110221e+00  1.68e-05 3.55e-14  1.68e-06     0s
#   16   1.58126219e+00  1.58116755e+00  5.44e-06 3.38e-14  8.34e-07     1s
#   17   1.58124904e+00  1.58121813e+00  1.26e-06 3.55e-14  2.73e-07     1s
#   18   1.58124450e+00  1.58123227e+00  2.47e-07 2.13e-14  1.09e-07     1s
#   19   1.58124371e+00  1.58123783e+00  9.10e-08 3.20e-14  5.22e-08     1s
#   20   1.58124330e+00  1.58124125e+00  2.96e-08 2.84e-14  1.83e-08     1s
#   21   1.58124316e+00  1.58124228e+00  7.25e-09 2.49e-14  7.83e-09     1s
#   22   1.58124311e+00  1.58124306e+00  1.20e-09 3.20e-14  4.74e-10     1s
#   23   1.58124309e+00  1.58124309e+00  4.11e-10 2.66e-14  5.05e-12     1s
#
# Barrier solved model in 23 iterations and 0.62 seconds (0.59 work units)
# Optimal objective 1.58124309e+00
#
# Crossover log...
#
#       16 DPushes remaining with DInf 0.0000000e+00                 1s
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#       37 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.1927126e-11      1s
#
#
# Solved with barrier
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#       56    1.5812431e+00   0.000000e+00   0.000000e+00      1s
#
# Solved in 56 iterations and 0.69 seconds (0.64 work units)
# Optimal objective  1.581243093e+00
#   1%|▏                                        | 11/2000 [00:08<29:56,  1.11it/s]
# Set parameter FeasibilityTol to value 1e-08
# Set parameter LPWarmStart to value 2
# Warning on update mode = 1 after new variables or constraints added:
# Setting LP warm start basis or start ignored
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 28672 rows, 87536 columns and 612752 nonzeros
# Model fingerprint: 0x3040c8f5
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-05, 2e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e-04, 2e-01]
# Presolve removed 23714 rows and 72607 columns
# Presolve time: 0.08s
# Presolved: 4958 rows, 14929 columns, 103864 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.14s
#
# Barrier statistics:
#  AA' NZ     : 7.786e+04
#  Factor NZ  : 1.078e+06 (roughly 17 MB of memory)
#  Factor Ops : 4.112e+08 (less than 1 second per iteration)
#  Threads    : 6
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   5.92578626e+01 -6.48228855e+00  9.97e+01 9.67e+00  1.58e+00     0s
#    1   9.62585504e+00 -3.75069345e+00  1.39e+01 2.13e-14  2.41e-01     0s
#    2   3.02579862e+00 -1.77510844e-01  2.49e+00 2.13e-14  4.73e-02     0s
#    3   1.97308124e+00  9.59114745e-01  6.75e-01 3.20e-14  1.39e-02     0s
#    4   1.64359563e+00  1.36064534e+00  1.05e-01 5.33e-14  3.20e-03     0s
#    5   1.59812328e+00  1.49926729e+00  2.63e-02 3.91e-14  9.97e-04     0s
#    6   1.58663597e+00  1.55037488e+00  6.87e-03 3.20e-14  3.36e-04     0s
#    7   1.58423931e+00  1.56438057e+00  3.53e-03 3.20e-14  1.77e-04     0s
#    8   1.58256262e+00  1.57164385e+00  1.62e-03 3.02e-14  9.44e-05     0s
#    9   1.58152270e+00  1.57541516e+00  7.51e-04 2.31e-14  5.19e-05     0s
#   10   1.58077389e+00  1.57768492e+00  2.68e-04 2.13e-14  2.61e-05     0s
#   11   1.58033244e+00  1.57933667e+00  6.70e-05 2.31e-14  8.41e-06     0s
#   12   1.58018864e+00  1.57972751e+00  3.40e-05 2.13e-14  3.88e-06     0s
#   13   1.58010260e+00  1.57985116e+00  1.61e-05 2.13e-14  2.12e-06     0s
#   14   1.58006591e+00  1.57993230e+00  9.45e-06 2.13e-14  1.12e-06     1s
#   15   1.58003950e+00  1.57996636e+00  4.92e-06 1.78e-14  6.16e-07     1s
#   16   1.58002561e+00  1.57998708e+00  2.68e-06 1.78e-14  3.24e-07     1s
#   17   1.58001444e+00  1.57999873e+00  9.38e-07 1.60e-14  1.33e-07     1s
#   18   1.58000961e+00  1.58000447e+00  2.15e-07 1.60e-14  4.36e-08     1s
#   19   1.58000829e+00  1.58000717e+00  3.87e-08 1.95e-14  9.55e-09     1s
#   20   1.58000797e+00  1.58000788e+00  2.52e-09 2.13e-14  7.72e-10     1s
#   21   1.58000795e+00  1.58000793e+00  6.31e-10 2.13e-14  1.63e-10     1s
#   22   1.58000794e+00  1.58000794e+00  3.66e-10 2.13e-14  1.44e-11     1s
#
# Barrier solved model in 22 iterations and 0.64 seconds (0.60 work units)
# Optimal objective 1.58000794e+00
#
# Crossover log...
#
#       89 DPushes remaining with DInf 0.0000000e+00                 1s
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#       75 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.0618839e-11      1s
#
#
# Solved with barrier
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      167    1.5800079e+00   0.000000e+00   0.000000e+00      1s
#
# Solved in 167 iterations and 0.73 seconds (0.68 work units)
# Optimal objective  1.580007938e+00
#   1%|▏                                        | 12/2000 [00:09<31:41,  1.05it/s]
# Set parameter FeasibilityTol to value 1e-08
# Set parameter LPWarmStart to value 2
# Warning on update mode = 1 after new variables or constraints added:
# Setting LP warm start basis or start ignored
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 28672 rows, 91754 columns and 642278 nonzeros
# Model fingerprint: 0xc5461d03
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-05, 2e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e-04, 2e-01]
# Presolve removed 23647 rows and 75951 columns
# Presolve time: 0.08s
# Presolved: 5025 rows, 15803 columns, 110178 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.16s
#
# Barrier statistics:
#  AA' NZ     : 8.183e+04
#  Factor NZ  : 1.152e+06 (roughly 18 MB of memory)
#  Factor Ops : 4.583e+08 (less than 1 second per iteration)
#  Threads    : 6
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   6.10571997e+01 -7.04772619e+00  1.25e+02 9.96e+00  1.55e+00     0s
#    1   1.06119094e+01 -3.92278643e+00  1.90e+01 2.95e-14  2.53e-01     0s
#    2   3.27597204e+00 -1.01160494e-01  3.56e+00 3.02e-14  4.98e-02     0s
#    3   2.05509281e+00  9.22913592e-01  9.94e-01 1.95e-14  1.52e-02     0s
#    4   1.65877520e+00  1.31979360e+00  1.61e-01 3.29e-14  3.68e-03     0s
#    5   1.60087419e+00  1.47788781e+00  3.85e-02 2.49e-14  1.18e-03     0s
#    6   1.58782867e+00  1.55002331e+00  1.17e-02 3.20e-14  3.41e-04     0s
#    7   1.58366805e+00  1.56258409e+00  4.57e-03 4.97e-14  1.79e-04     0s
#    8   1.58214823e+00  1.57070451e+00  2.54e-03 3.20e-14  9.37e-05     0s
#    9   1.58088231e+00  1.57404909e+00  1.23e-03 2.49e-14  5.49e-05     0s
#   10   1.57997541e+00  1.57719786e+00  4.94e-04 1.78e-14  2.20e-05     0s
#   11   1.57947139e+00  1.57820123e+00  2.10e-04 3.02e-14  9.99e-06     0s
#   12   1.57921240e+00  1.57866967e+00  9.40e-05 2.13e-14  4.25e-06     1s
#   13   1.57906882e+00  1.57881083e+00  3.56e-05 2.49e-14  2.03e-06     1s
#   14   1.57902359e+00  1.57887133e+00  1.91e-05 2.13e-14  1.20e-06     1s
#   15   1.57899728e+00  1.57891154e+00  1.00e-05 2.31e-14  6.77e-07     1s
#   16   1.57898462e+00  1.57894312e+00  5.85e-06 1.95e-14  3.26e-07     1s
#   17   1.57896707e+00  1.57895965e+00  2.69e-07 1.78e-14  5.96e-08     1s
#   18   1.57896579e+00  1.57896456e+00  1.74e-08 1.78e-14  9.93e-09     1s
#   19   1.57896567e+00  1.57896523e+00  4.06e-09 1.42e-14  3.57e-09     1s
#   20   1.57896562e+00  1.57896559e+00  1.72e-10 2.13e-14  2.86e-10     1s
#   21   1.57896561e+00  1.57896561e+00  2.49e-11 1.95e-14  9.97e-13     1s
#
# Barrier solved model in 21 iterations and 0.65 seconds (0.63 work units)
# Optimal objective 1.57896561e+00
#
# Crossover log...
#
#       13 DPushes remaining with DInf 0.0000000e+00                 1s
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#       26 PPushes remaining with PInf 0.0000000e+00                 1s
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.1480705e-11      1s
#
#
# Solved with barrier
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#       42    1.5789656e+00   0.000000e+00   0.000000e+00      1s
#
# Solved in 42 iterations and 0.72 seconds (0.69 work units)
# Optimal objective  1.578965612e+00
#   1%|▎                                        | 13/2000 [00:10<32:51,  1.01it/s]
# Set parameter FeasibilityTol to value 1e-08
# Set parameter LPWarmStart to value 2
# Warning on update mode = 1 after new variables or constraints added:
# Setting LP warm start basis or start ignored
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 28672 rows, 94432 columns and 661024 nonzeros
# Model fingerprint: 0x885d7fac
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-05, 2e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e-04, 2e-01]
# Presolve removed 23604 rows and 77811 columns
# Presolve time: 0.08s
# Presolved: 5068 rows, 16621 columns, 115234 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.14s
#
# Barrier statistics:
#  AA' NZ     : 8.495e+04
#  Factor NZ  : 1.231e+06 (roughly 20 MB of memory)
#  Factor Ops : 5.175e+08 (less than 1 second per iteration)
#  Threads    : 6
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   6.40593271e+01 -7.90993908e+00  9.69e+01 1.00e+01  1.58e+00     0s
#    1   1.09204897e+01 -4.23215878e+00  1.45e+01 2.93e-14  2.55e-01     0s
#    2   3.34450849e+00 -1.34160340e-01  2.74e+00 2.13e-14  5.00e-02     0s
#    3   1.98339043e+00  8.33227956e-01  6.23e-01 2.31e-14  1.41e-02     0s
#    4   1.65180387e+00  1.24454246e+00  1.09e-01 3.02e-14  4.02e-03     0s
#    5   1.60027806e+00  1.45481575e+00  2.87e-02 3.91e-14  1.30e-03     0s
# ...
#    8   1.54541422e+00  1.53734310e+00  1.10e-03 1.20e-14  1.59e-05     1s
#    9   1.54298735e+00  1.53901148e+00  4.03e-04 7.11e-15  7.79e-06     1s
#   10   1.54220263e+00  1.54006714e+00  2.31e-04 7.99e-15  4.17e-06     1s
#   11   1.54173461e+00  1.54039492e+00  1.41e-04 7.11e-15  2.61e-06     1s
#   12   1.54144268e+00  1.54060140e+00  8.72e-05 5.77e-15  1.64e-06     1s
#   13   1.54125751e+00  1.54073635e+00  5.40e-05 6.22e-15  1.02e-06     1s
#   14   1.54109910e+00  1.54082947e+00  2.67e-05 8.88e-15  5.25e-07     1s
#   15   1.54099978e+00  1.54088805e+00  1.02e-05 6.22e-15  2.18e-07     1s
#   16   1.54095426e+00  1.54092212e+00  3.04e-06 8.88e-15  6.26e-08     1s
#   17   1.54093607e+00  1.54093127e+00  4.34e-07 8.88e-15  9.36e-09     1s
#   18   1.54093313e+00  1.54093240e+00  3.50e-08 7.99e-15  1.44e-09     1s
#   19   1.54093291e+00  1.54093267e+00  1.11e-08 8.88e-15  4.81e-10     2s
#   20   1.54093282e+00  1.54093278e+00  1.62e-09 1.33e-14  7.33e-11     2s
#   21   1.54093280e+00  1.54093280e+00  1.57e-10 7.99e-15  5.35e-12     2s
#
# Barrier solved model in 21 iterations and 1.62 seconds (1.79 work units)
# Optimal objective 1.54093280e+00
#
# Crossover log...
#
#       43 DPushes remaining with DInf 0.0000000e+00                 2s
#        0 DPushes remaining with DInf 0.0000000e+00                 2s
#
#      145 PPushes remaining with PInf 0.0000000e+00                 2s
#        0 PPushes remaining with PInf 0.0000000e+00                 2s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 8.7387061e-02      2s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      191    1.5409328e+00   0.000000e+00   8.738706e-02      2s
#
# Solved with barrier
#      194    1.5409328e+00   0.000000e+00   0.000000e+00      2s
#
# Solved in 194 iterations and 1.83 seconds (2.00 work units)
# Optimal objective  1.540932801e+00
#   2%|▋                                      | 36/2000 [00:52<1:11:43,  2.19s/it]
# Set parameter FeasibilityTol to value 1e-08
# Set parameter LPWarmStart to value 2
# Warning on update mode = 1 after new variables or constraints added:
# Setting LP warm start basis or start ignored
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 28672 rows, 149778 columns and 1048446 nonzeros
# Model fingerprint: 0xf5396832
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-05, 2e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e-04, 2e-01]
# Presolve removed 22734 rows and 117116 columns
# Presolve time: 0.17s
# Presolved: 5938 rows, 32662 columns, 225694 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.26s
#
# Barrier statistics:
#  AA' NZ     : 1.545e+05
#  Factor NZ  : 2.807e+06 (roughly 40 MB of memory)
#  Factor Ops : 2.136e+09 (less than 1 second per iteration)
#  Threads    : 6
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.13666948e+02 -1.24147806e+01  1.63e+02 5.09e+00  7.31e-01     1s
#    1   1.80156929e+01 -5.67198532e+00  2.41e+01 1.60e-14  1.14e-01     1s
#    2   3.77951254e+00 -3.89494099e-01  3.26e+00 1.47e-14  1.65e-02     1s
#    3   2.12250477e+00  8.05596568e-01  8.34e-01 1.02e-14  4.81e-03     1s
#    4   1.65878682e+00  1.27276088e+00  1.48e-01 1.47e-14  1.14e-03     1s
#    5   1.57522259e+00  1.44015954e+00  2.80e-02 1.20e-14  3.21e-04     1s
#    6   1.55981809e+00  1.48865178e+00  1.21e-02 1.11e-14  1.56e-04     1s
#    7   1.55177676e+00  1.52123655e+00  5.15e-03 9.33e-15  6.26e-05     1s
#    8   1.54698505e+00  1.52985116e+00  2.42e-03 8.88e-15  3.40e-05     1s
#    9   1.54398053e+00  1.53366506e+00  1.34e-03 7.99e-15  2.02e-05     1s
#   10   1.54190102e+00  1.53633562e+00  7.04e-04 8.88e-15  1.08e-05     1s
#   11   1.54038590e+00  1.53763160e+00  2.93e-04 7.11e-15  5.35e-06     1s
#   12   1.53969268e+00  1.53846088e+00  1.37e-04 7.99e-15  2.38e-06     1s
#   13   1.53928719e+00  1.53880317e+00  5.16e-05 8.88e-15  9.36e-07     1s
#   14   1.53907527e+00  1.53893223e+00  1.21e-05 1.07e-14  2.77e-07     1s
#   15   1.53901711e+00  1.53897517e+00  3.01e-06 8.88e-15  8.14e-08     1s
#   16   1.53900330e+00  1.53898959e+00  1.10e-06 7.11e-15  2.66e-08     1s
#   17   1.53899797e+00  1.53899268e+00  3.84e-07 7.99e-15  1.03e-08     1s
#   18   1.53899586e+00  1.53899420e+00  1.21e-07 1.07e-14  3.22e-09     1s
#   19   1.53899495e+00  1.53899471e+00  1.18e-08 8.88e-15  4.67e-10     1s
#   20   1.53899483e+00  1.53899482e+00  4.29e-11 8.88e-15  1.47e-11     1s
#
# Barrier solved model in 20 iterations and 1.45 seconds (1.73 work units)
# Optimal objective 1.53899483e+00
#
# Crossover log...
#
#      298 DPushes remaining with DInf 0.0000000e+00                 1s
#        0 DPushes remaining with DInf 0.0000000e+00                 2s
#
#       60 PPushes remaining with PInf 0.0000000e+00                 2s
#        0 PPushes remaining with PInf 0.0000000e+00                 2s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 2.1258981e-11      2s
#
#
# Solved with barrier
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      361    1.5389948e+00   0.000000e+00   0.000000e+00      2s
#
# Solved in 361 iterations and 1.66 seconds (1.95 work units)
# Optimal objective  1.538994829e+00
#   2%|▋                                      | 37/2000 [00:54<1:11:19,  2.18s/it]
# Set parameter FeasibilityTol to value 1e-08
# Set parameter LPWarmStart to value 2
# Warning on update mode = 1 after new variables or constraints added:
# Setting LP warm start basis or start ignored
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 28672 rows, 151135 columns and 1057945 nonzeros
# Model fingerprint: 0x78a4c72b
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-05, 2e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e-04, 2e-01]
# Presolve removed 22721 rows and 118057 columns
# Presolve time: 0.16s
# Presolved: 5951 rows, 33078 columns, 230427 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.28s
#
# Barrier statistics:
#  AA' NZ     : 1.572e+05
#  Factor NZ  : 2.924e+06 (roughly 40 MB of memory)
#  Factor Ops : 2.317e+09 (less than 1 second per iteration)
#  Threads    : 6
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.13397666e+02 -1.20265699e+01  2.09e+02 5.14e+00  7.20e-01     1s
#    1   1.71143939e+01 -5.50385040e+00  2.89e+01 1.25e-14  1.06e-01     1s
#    2   3.69355136e+00 -4.16411031e-01  3.98e+00 1.35e-14  1.58e-02     1s
#    3   2.02333695e+00  7.62184032e-01  8.76e-01 1.02e-14  4.25e-03     1s
#    4   1.63724347e+00  1.22664587e+00  1.48e-01 1.44e-14  1.09e-03     1s
#    5   1.57784361e+00  1.41931172e+00  4.09e-02 1.49e-14  3.70e-04     1s
#    6   1.55365341e+00  1.51028011e+00  7.07e-03 1.69e-14  8.85e-05     1s
#    7   1.54490055e+00  1.52723905e+00  1.66e-03 1.29e-14  3.45e-05     1s
#    8   1.54115125e+00  1.53277932e+00  5.73e-04 1.87e-14  1.62e-05     1s
#    9   1.53970259e+00  1.53484394e+00  3.10e-04 7.11e-15  9.37e-06     1s
#   10   1.53849429e+00  1.53610755e+00  1.27e-04 8.88e-15  4.60e-06     1s
#   11   1.53807915e+00  1.53669194e+00  7.35e-05 8.88e-15  2.67e-06     1s
#   12   1.53781305e+00  1.53698771e+00  4.17e-05 7.33e-15  1.59e-06     1s
#   13   1.53762906e+00  1.53717649e+00  2.11e-05 7.11e-15  8.72e-07     1s
#   14   1.53752948e+00  1.53727707e+00  1.06e-05 8.88e-15  4.86e-07     1s
#   15   1.53746597e+00  1.53735757e+00  4.02e-06 8.88e-15  2.09e-07     1s
#   16   1.53742806e+00  1.53740724e+00  4.62e-07 1.15e-14  4.02e-08     1s
#   17   1.53742199e+00  1.53741835e+00  3.73e-08 7.99e-15  7.05e-09     1s
#   18   1.53742128e+00  1.53742086e+00  5.12e-09 8.88e-15  8.18e-10     1s
#   19   1.53742111e+00  1.53742108e+00  1.02e-10 1.07e-14  7.31e-11     2s
#   20   1.53742111e+00  1.53742111e+00  8.50e-11 1.07e-14  3.62e-12     2s
#
# Barrier solved model in 20 iterations and 1.55 seconds (1.86 work units)
# Optimal objective 1.53742111e+00
#
# Crossover log...
#
#       77 DPushes remaining with DInf 0.0000000e+00                 2s
#        0 DPushes remaining with DInf 0.0000000e+00                 2s
#
#       48 PPushes remaining with PInf 0.0000000e+00                 2s
#        0 PPushes remaining with PInf 0.0000000e+00                 2s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.6119134e-11      2s
#
#
# Solved with barrier
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      128    1.5374211e+00   0.000000e+00   0.000000e+00      2s
#
# Solved in 128 iterations and 1.69 seconds (2.00 work units)
# Optimal objective  1.537421107e+00
#   2%|▋                                      | 38/2000 [00:56<1:11:26,  2.19s/it]
# Set parameter FeasibilityTol to value 1e-08
# Set parameter LPWarmStart to value 2
# Warning on update mode = 1 after new variables or constraints added:
# Setting LP warm start basis or start ignored
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 28672 rows, 151727 columns and 1062089 nonzeros
# Model fingerprint: 0xe1d2f711
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-05, 2e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e-04, 2e-01]
# Presolve removed 22719 rows and 118558 columns
# Presolve time: 0.16s
# Presolved: 5953 rows, 33169 columns, 230243 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.27s
#
# Barrier statistics:
#  AA' NZ     : 1.575e+05
#  Factor NZ  : 2.929e+06 (roughly 40 MB of memory)
#  Factor Ops : 2.321e+09 (less than 1 second per iteration)
#  Threads    : 6
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.12999374e+02 -1.16734877e+01  1.63e+02 5.15e+00  7.14e-01     1s
#    1   1.76405461e+01 -5.36862676e+00  2.38e+01 1.33e-14  1.10e-01     1s
#    2   3.72208219e+00 -2.57501507e-01  3.21e+00 1.15e-14  1.57e-02     1s
#    3   2.04615697e+00  8.13673077e-01  7.31e-01 9.55e-15  4.27e-03     1s
#    4   1.65517035e+00  1.27619036e+00  1.46e-01 1.24e-14  1.10e-03     1s
#    5   1.57750375e+00  1.43516485e+00  3.26e-02 1.29e-14  3.38e-04     1s
#    6   1.55328215e+00  1.51545863e+00  6.20e-03 1.42e-14  7.79e-05     1s
#    7   1.54488334e+00  1.52808534e+00  1.66e-03 1.07e-14  3.29e-05     1s
#    8   1.54150283e+00  1.53321930e+00  7.29e-04 9.77e-15  1.60e-05     1s
#    9   1.53905097e+00  1.53534377e+00  2.48e-04 8.88e-15  7.13e-06     1s
#   10   1.53820545e+00  1.53631609e+00  1.24e-04 9.77e-15  3.62e-06     1s
#   11   1.53780792e+00  1.53676637e+00  7.41e-05 9.77e-15  2.00e-06     1s
#   12   1.53752895e+00  1.53690928e+00  4.06e-05 7.99e-15  1.19e-06     1s
#   13   1.53736505e+00  1.53702427e+00  2.19e-05 7.99e-15  6.53e-07     1s
#   14   1.53728597e+00  1.53709007e+00  1.33e-05 7.99e-15  3.75e-07     1s
#   15   1.53721160e+00  1.53712585e+00  5.33e-06 7.99e-15  1.64e-07     1s
#   16   1.53717569e+00  1.53715061e+00  1.64e-06 8.88e-15  4.80e-08     1s
#   17   1.53716354e+00  1.53715775e+00  4.57e-07 1.15e-14  1.11e-08     1s
#   18   1.53715932e+00  1.53715846e+00  6.95e-08 8.88e-15  1.65e-09     1s
#   19   1.53715876e+00  1.53715851e+00  1.88e-08 8.88e-15  4.60e-10     1s
#   20   1.53715855e+00  1.53715853e+00  7.22e-10 8.88e-15  3.02e-11     1s
#
# Barrier solved model in 20 iterations and 1.49 seconds (1.85 work units)
# Optimal objective 1.53715855e+00
#
# Crossover log...
#
#      164 DPushes remaining with DInf 0.0000000e+00                 2s
#        0 DPushes remaining with DInf 0.0000000e+00                 2s
#
#      375 PPushes remaining with PInf 0.0000000e+00                 2s
#        0 PPushes remaining with PInf 0.0000000e+00                 2s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.5012991e-11      2s
#
#
# Solved with barrier
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      542    1.5371585e+00   0.000000e+00   0.000000e+00      2s
#
# Solved in 542 iterations and 1.69 seconds (2.04 work units)
# Optimal objective  1.537158534e+00
#   2%|▊                                      | 39/2000 [00:58<1:11:31,  2.19s/it]
# Set parameter FeasibilityTol to value 1e-08
# Set parameter LPWarmStart to value 2
# Warning on update mode = 1 after new variables or constraints added:
# Setting LP warm start basis or start ignored
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 28672 rows, 153910 columns and 1077370 nonzeros
# Model fingerprint: 0xf3ff4a55
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-05, 2e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e-04, 2e-01]
# Presolve removed 22682 rows and 119895 columns
# Presolve time: 0.17s
# Presolved: 5990 rows, 34015 columns, 236038 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.28s
#
# Barrier statistics:
#  AA' NZ     : 1.619e+05
#  Factor NZ  : 2.994e+06 (roughly 40 MB of memory)
#  Factor Ops : 2.416e+09 (less than 1 second per iteration)
#  Threads    : 6
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.19899320e+02 -1.17901198e+01  2.18e+02 5.18e+00  7.31e-01     1s
#    1   1.84491158e+01 -5.52308139e+00  3.10e+01 1.13e-14  1.10e-01     1s
#    2   3.82513556e+00 -3.03130294e-01  4.18e+00 1.42e-14  1.58e-02     1s
#    3   2.10200170e+00  8.29666004e-01  1.01e+00 1.06e-14  4.36e-03     1s
#    4   1.65559549e+00  1.25466304e+00  1.86e-01 1.42e-14  1.11e-03     1s
#    5   1.57180516e+00  1.44607906e+00  3.37e-02 1.15e-14  2.85e-04     1s
#    6   1.54854830e+00  1.50967264e+00  3.80e-03 1.15e-14  7.55e-05     1s
#    7   1.54146177e+00  1.52694619e+00  1.10e-03 9.77e-15  2.74e-05     1s
#    8   1.53783697e+00  1.53134364e+00  3.09e-04 7.11e-15  1.22e-05     1s
#    9   1.53635862e+00  1.53301404e+00  1.35e-04 7.11e-15  6.28e-06     1s
#   10   1.53564967e+00  1.53372550e+00  6.84e-05 8.88e-15  3.61e-06     1s
#   11   1.53533633e+00  1.53415755e+00  4.26e-05 7.11e-15  2.21e-06     1s
#   12   1.53510475e+00  1.53443028e+00  2.48e-05 7.99e-15  1.26e-06     1s
#   13   1.53498654e+00  1.53455045e+00  1.62e-05 7.11e-15  8.17e-07     1s
#   14   1.53486606e+00  1.53464373e+00  7.81e-06 5.33e-15  4.17e-07     1s
#   15   1.53479240e+00  1.53470473e+00  2.87e-06 7.11e-15  1.64e-07     1s
#   16   1.53476224e+00  1.53473653e+00  9.49e-07 7.99e-15  4.82e-08     1s
#   17   1.53474899e+00  1.53474419e+00  1.59e-07 7.99e-15  8.99e-09     1s
#   18   1.53474630e+00  1.53474584e+00  1.14e-08 7.99e-15  8.52e-10     1s
#   19   1.53474606e+00  1.53474602e+00  7.19e-10 8.88e-15  7.91e-11     2s
#   20   1.53474604e+00  1.53474604e+00  8.21e-11 9.77e-15  7.99e-12     2s
#
# Barrier solved model in 20 iterations and 1.55 seconds (1.92 work units)
# Optimal objective 1.53474604e+00
#
# Crossover log...
#
#      117 DPushes remaining with DInf 0.0000000e+00                 2s
#        0 DPushes remaining with DInf 0.0000000e+00                 2s
#
#      144 PPushes remaining with PInf 0.0000000e+00                 2s
#        0 PPushes remaining with PInf 0.0000000e+00                 2s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 7.1470330e-12      2s
#
#
# Solved with barrier
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      264    1.5347460e+00   0.000000e+00   0.000000e+00      2s
#
# Solved in 264 iterations and 1.73 seconds (2.10 work units)
# Optimal objective  1.534746037e+00
#   2%|▊                                        | 40/2000 [01:01<49:57,  1.53s/it]

# %%
ga.plot()

# %%
plot(ga)
# Out:
# the final cost is 1.5271887482640834

# %%
stats(ga)
# Out:
# obj_cost:  0.5494099632692535
# average_memory:  nan
# average_time_LP:  0.45521082327916074
# average_children_sampled:  2215.076923076923
# /opt/anaconda3/envs/Genetic_OT/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /opt/anaconda3/envs/Genetic_OT/lib/python3.10/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
plot(ga)
# Out:
# the final cost is 2.1927353639726332

# %%
plot(ga)
# Out:
# the final cost is 1.1686430628118674

# %%
plt.scatter(np.array(ga.cost[:-1])-np.array(ga.cost[1:]), ga.time_model[1:])

# %%
import pandas as pd

# %%
df = pd.DataFrame(columns=['n_imgs', 'dim_img','char','turnover_rate', 'beta','parent_to_children','random_selection','parent_changed','add_neighbours','radius', "obj_cost","average_memory","average_time_LP","average_children_sampled","n_iter","total_time"])

# %%
df = pd.read_csv("parameters.csv", index_col=False)

# %%
'n_imgs', 'dim_img','char','turnover_rate', 'beta','parent_to_children','random_selection','parent_changed','add_neighbours','radius', "obj_cost","average_memory","average_time_LP","average_children_sampled","n_iter","total_time"
# Out:
#   turnover_rate beta parent_to_children random_selection parent_changed  \
# 0             1    6                  1            False              1
#
#   add_neighbours radius  obj_cost  average_memory  average_time_LP  \
# 0           True      2  0.627147        6.333333         0.550389
#
#    average_children_sampled
# 0                8783.12037

# %%
df
# Out:
#     n_imgs  dim_img char  turnover_rate  beta  parent_to_children  \
# 0        2       64  zoo           1.00     2                   1
# 1        2       64  zoo           1.00     2                   1
# 2        2       64  zoo           0.10     2                   1
# 3        2       64  zoo           0.01     2                   1
# 4        2       64  zoo           1.00     2                   1
# 5        2       64  zoo           0.10     2                   1
# 6        2       64  zoo           0.01     2                   1
# 7        2       64  zoo           1.00     2                   1
# 8        2       64  zoo           0.10     2                   1
# 9        2       64  zoo           0.01     2                   1
# 10       3       64  zoo           1.00     2                   1
# 11       3       64  zoo           0.10     2                   1
# 12       3       64  zoo           0.01     2                   1
# 13       3       64  zoo           1.00     2                   1
# 14       3       64  zoo           0.10     2                   1
# 15       3       64  zoo           0.01     2                   1
# 16       3       64  zoo           1.00     2                   1
# 17       3       64  zoo           0.10     2                   1
# 18       3       64  zoo           0.01     2                   1
# 19       4       64  zoo           1.00     2                   1
#
#     random_selection  parent_changed  add_neighbours  radius  obj_cost  \
# 0              False               1           False       2  0.008667
# 1              False               1           False       2  0.008666
# 2              False               1           False       2  0.009506
# 3              False               1           False       2  0.009439
# 4              False               1           False       2  0.004128
# 5              False               1           False       2  0.004694
# 6              False               1           False       2  0.007311
# 7              False               1           False       2  0.003349
# 8              False               1           False       2  0.003885
# 9              False               1           False       2  0.006035
# 10             False               1           False       2  0.014393
# 11             False               1           False       2  0.017588
# 12             False               1           False       2  0.024366
# 13             False               1           False       2  0.014379
# 14             False               1           False       2  0.018139
# 15             False               1           False       2  0.023967
# 16             False               1           False       2  0.016175
# 17             False               1           False       2  0.018751
# 18             False               1           False       2  0.025209
# 19             False               1           False       2  0.035677
#
#     average_memory  average_time_LP  average_children_sampled  n_iter  \
# 0       140.000000         0.081215                 52.541000    1000
# 1       138.571429         0.254299                 54.645000    1000
# 2       469.500000         0.207050                 14.191000    1000
# 3         8.247934         0.232107                994.037000    1000
# 4        73.625000         0.363069                 69.318000    1000
# 5       198.000000         0.265970                 17.828000    1000
# 6       769.000000         0.233531                  4.882000    1000
# 7       107.222222         0.361090                 77.149000    1000
# 8       217.000000         0.261701                 17.032000    1000
# 9       979.000000         0.271391                  4.160000    1000
# 10       26.200000         7.410891                400.000000     162
# 11      139.000000         3.670714                 49.498471     327
# 12             NaN         1.450325                  6.129697     825
# 13       12.250000        17.971210                815.818182      66
# 14      103.000000         8.172171                 81.780822     146
# 15             NaN         3.385868                  9.842254     355
# 16       23.400000         8.142809                442.217687     147
# 17      117.000000         4.081441                 57.064846     293
# 18             NaN         1.549655                  6.686528     772
# 19       11.500000        27.319022                957.333333      45
#
#      total_time
# 0     81.295768
# 1    254.553454
# 2    207.257050
# 3    232.339454
# 4    363.431718
# 5    266.235711
# 6    233.764591
# 7    361.450974
# 8    261.962981
# 9    271.662589
# 10  1207.975193
# 11  1203.994230
# 12  1197.968462
# 13  1204.071093
# 14  1201.309136
# 15  1205.368923
# 16  1205.135785
# 17  1199.943586
# 18  1197.883003
# 19  1256.675013

# %%
df.boxplot(column='obj_cost',by=['turnover_rate', "n_imgs"])
# Out:
# <Axes: title={'center': 'obj_cost'}, xlabel='[turnover_rate, n_imgs]'>

# %% [markdown]
# #####
