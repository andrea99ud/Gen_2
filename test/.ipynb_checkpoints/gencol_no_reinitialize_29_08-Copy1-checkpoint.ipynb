# %%
def plot(data):
    figure, axis = plt.subplots(2, 3)

    axis[0][0].plot(data.cost)
    axis[0][0].set_title("cost transport")
    #axis[0].set_ylim((0, 2))

    axis[0][1].plot(data.time_child)
    axis[0][1].set_title("time to find a child")
    #axis[1].set_ylim((0, 0.01))

    axis[0][2].plot(data.time_model)
    axis[0][2].set_title("LP time")
    #axis[2].set_ylim((0, 0.5))

    axis[1][0].plot(data.n_children)
    axis[1][0].set_title("number sites")

    axis[1][1].boxplot(data.memory)
    axis[1][1].set_title("number of memory slot")

    #axis[1][2].plot(np.array(data.cost[:-1])-np.array(data.cost[1:]))
    #axis[1][2].set_title("improvements")
    
    axis[1][2].plot(data.n_best)
    axis[1][2].set_title("number best children")


    figure.set_size_inches(18.5, 10.5)

    plt.show()

    print(f"the final cost is {data.cost[-1]}")
    
import matplotlib.pyplot as plt
import numpy as np
from tqdm import tqdm
from PIL import Image
import scipy.sparse as sp
import scipy
import time
import itertools
import scipy
import cvxpy as cp
import random
import matplotlib
import math
import gurobipy as gp
from gurobipy import GRB

def create_array(orig_array, percentage):
    # Compute the number of unique rows we'll use
    num_rows = int(orig_array.shape[0] *percentage)
    
    # If num_rows is zero, we should at least select one row.
    num_rows = max(1, num_rows)
    
    # Randomly select 'num_rows' row indices without replacement
    unique_indices = np.random.choice(orig_array.shape[0], size=num_rows, replace=False)

    # Select the unique rows from the original array
    unique_rows = orig_array[unique_indices, :]
    
    # Now, we'll need to repeat these rows to fill the new array
    num_repeats = int(np.ceil(orig_array.shape[0] / float(num_rows)))

    # Repeat the unique rows to create a new array
    new_array = np.repeat(unique_rows, num_repeats, axis=0)
    
    # Make sure the new array has the same number of rows as the original array
    new_array = new_array[:orig_array.shape[0], :]
    
    return new_array

class Genetic_Algorithm:
    def __init__(self, img_list):
        
        
        self.N = img_list[0].shape[0]
        self.dim = len(img_list[0].shape)
        self.imgs = np.array([img.flatten() for img in img_list])
        self.b_eq = np.concatenate(self.imgs)
        self.non_zero_indices = []
        self.n_imgs = len(self.imgs)
       
        
        
         #stats
        self.cost = []
        self.time_child = []
        self.children_sampled = []
        self.time_model = []
        self.len_children = []
        self.n_children = []
        self.memory=[]
        self.n_best=[]
        
        start = time.time()
        print("initializing omega...")
        self.initialize_omega(add_diag=False)
        print("omega initialized in %5.3f. s" %(time.time()-start))
        
        start = time.time()
        print("initializing cost vector...")
        self.current_cost_vector = self.get_cost(self.active_indices)
        print("cost vector initialized in %5.3f. s" %(time.time()-start))
       
        start = time.time()
        print("initializing full model...")
        self.initialize_model()
        print("full model initialized in %5.3f. s" %(time.time()-start))

       
        
    def initialize_omega(self, add_diag=False):
        #the north west rule is used to initialise omega
        #we start with the first pixel of each image
        indices = np.zeros(self.n_imgs)
        omega = np.array(indices.copy())
        b = np.array([img[0] for img in self.imgs])

        current_gamma = [np.min(b)]
        while np.min(indices) < self.N**self.dim-1:
            gamma = np.min(b)
            b-=gamma
            low = np.where(b < 1e-9)[0]
            indices[low] +=1
            indices = np.clip(indices, a_min=0, a_max=self.N**self.dim-1)
            b[low] = self.imgs[low,indices[low].astype('int')]
            
            omega = np.vstack((omega,indices.copy()))
            current_gamma.append(gamma)
        
        self.current_gamma = np.array(current_gamma)
        self.active_indices = np.array(omega).astype('int')
        if add_diag:
            self.current_gamma = np.concatenate((self.current_gamma, np.zeros(self.N**self.dim)))
            self.active_indices = np.vstack((self.active_indices, np.repeat(np.arange(0,self.N**self.dim)[:, np.newaxis], self.n_imgs, axis=1)))
            
        
        
        
        
    def initialize_model(self):
        start = time.time()
        indices_row = np.array([])
        indices_col = np.array([])
        for i in range(self.n_imgs):
            for indices in range(self.N**self.dim):
                gamma_indices = np.where(self.active_indices.transpose()[i] == indices)[0]
                indices_row = np.concatenate((indices_row, gamma_indices))
                indices_col = np.concatenate((indices_col, np.ones(len(gamma_indices))*(indices+i*(self.N**self.dim))))

        A_eq = sp.csr_matrix((np.ones(len(indices_col)), (indices_col, indices_row)), shape=( (self.N**self.dim)*self.n_imgs, len(self.active_indices)))
        
        self.m = gp.Model("model")
        self.m.Params.UpdateMode = 1
        self.m.Params.LPWarmStart=2
        self.m.Params.Method=-1
        
        self.gamma = self.m.addMVar(shape=len(self.current_cost_vector), vtype=GRB.CONTINUOUS)
        #self.m.update()
        
        self.m.setObjective(self.current_cost_vector@self.gamma, GRB.MINIMIZE) 
        self.m.Params.OutputFlag = True
        self.m.Params.FeasibilityTol = 1e-8
        
        
        self.m.addMConstr(A_eq, self.gamma, '=', self.b_eq)
        
    
        self.m.optimize()
        self.time_model.append(time.time()-start)
        self.cost.append(self.m.ObjVal)
        self.current_gamma = np.array(self.gamma.X)
        self.current_kantorovich = np.array(self.m.PI)
        #self.constraints_RMP=A_eq
       
  

    def barycentric_distance(self, indices_list):
        # mean squared deviation from the classical barycenter of the xi
        #rescale x and y to be in [0,1]
       
        barycenter = np.sum(indices_list/self.N, axis=0)/self.n_imgs
        
        barycenter_cost = np.sum([np.sum((x - barycenter) ** 2, axis=0)/self.n_imgs for x in indices_list/self.N], axis=0)
      
        return barycenter_cost

    def get_cost(self, vector):
        #for each pair of active pixels, compute the cost of moving the first pixel to the second
        indices_list = []
        for i in range(self.n_imgs):
            indices_list.append(np.array(np.unravel_index(vector.transpose()[i], tuple([self.N for i in range(self.dim)]))))
        cost_vector = self.barycentric_distance(np.array(indices_list))
        return cost_vector

    def compute_gain(self, cost, children):
        gain = np.sum([self.current_kantorovich[i*(self.N**self.dim):(i+1)*(self.N**self.dim)][children.transpose()[i]] for i in range(self.n_imgs)], axis=0)-cost
        return gain

    def find_best_child(self):
        parent = self.non_zero_indices.copy().transpose()
       
        parent = create_array(parent, self.parent_to_children)
       
        index = random.sample(range(0, self.n_imgs), self.parent_changed)
        parent[index] = np.random.randint(0, self.N**self.dim, size=len(parent[1]))
        
        children = parent.copy().transpose()
        
        gain = self.compute_gain(self.get_cost(children), children)
        
        best_children = children[np.where(gain > 0)[0]]
       
        #now take the best turnover_rate% or just some random turnover_rate
        if not self.random_selection:                  
            best_children = children[np.argsort(gain)[-int(best_children.shape[0]*self.turnover_rate):]]
        else:
            chosen_children = np.random.choice(best_children.shape[0], size=int(best_children.shape[0]*self.turnover_rate), replace=False)
            best_children = best_children[chosen_children]
        
        if self.add_neighbours:
            for i in self.neighbours:
                parent[index] = np.clip(self.non_zero_indices.copy().transpose()[index]+i, 0, self.N**2-1)
                children = parent.copy().transpose()
                gain = self.compute_gain(self.get_cost(children), children)
                best_children = np.vstack((best_children,children[np.where(gain > 0)[0]]))

            
       
        return best_children

    
    def run(self, max_iter, max_sample, max_runtime, beta, turnover_rate, parent_to_children, random_selection, parent_changed, add_neighbours, radius):
        
        self.beta = beta
        self.turnover_rate = turnover_rate
        self.parent_to_children = parent_to_children
        self.random_selection = random_selection
        self.parent_changed = parent_changed
        self.add_neighbours = add_neighbours
        self.radius=radius
        self.neighbours= []
        self.iter=0
        for i in range(int(-self.N**2/2),int(self.N**2/2)):
                xx = i % self.N*np.sign(i)
                yy = int(i / self.N)
                mask = (xx)**2 + (yy)**2 < self.radius**2
                if not mask or i==0: continue
                self.neighbours.append(i)
        
        start_runtime = time.time()
        n_memory=0
        for _ in tqdm(range(max_iter)):
            if time.time() - start_runtime > max_runtime:
                break
            start_iter = time.time()
            self.non_zero_indices = self.active_indices[np.nonzero(self.current_gamma)]
            sample = 0
            #divide the non zero indices into chunks of size chunk_size
            best_children = self.find_best_child()
            while best_children.shape[0] < 2 and sample < max_sample:
                sample += 1
                best_children = self.find_best_child()
            if best_children.shape[0]<2:
                print("done?")
                break
            self.iter+=1
            self.children_sampled.append(sample)
            self.n_children.append(self.active_indices.shape[0])
            self.n_best.append(best_children.shape[0])
            
            
            
            self.current_cost_vector = np.append(self.current_cost_vector, self.get_cost(best_children))
            self.cost_children = self.get_cost(best_children)
            self.current_gamma = np.append(self.current_gamma, np.zeros(best_children.shape[0]))
            
            self.active_indices = np.vstack((self.active_indices, best_children))
            
            idx = best_children.copy().transpose()
            shift = np.array([i*(self.N**self.dim) for i in range(self.n_imgs)]).reshape(-1,1)
            idx = (idx+shift).transpose()
            #reshaped_arr = idx.reshape(-1).copy()
            #print(idx.shape)

            # Create an array for the second element in each tuple
            #second_elements = np.repeat(np.arange(len(best_children)), self.n_imgs)

            # Stack the two arrays
            #stacked_arr = np.vstack((reshaped_arr, second_elements))
          
            #A_children = sp.csr_matrix((np.ones(len(best_children)*self.n_imgs), (stacked_arr[0], stacked_arr[1])), shape=((self.N**self.dim)*self.n_imgs, len(best_children))).transpose()
            #self.constraints_RMP = sp.hstack((self.constraints_RMP, A_children))
            n_memory+=1
            
            self.time_child.append(time.time() - start_iter)
            
            
            if self.active_indices.shape[0] > int(self.beta*((self.N**self.dim)*self.n_imgs)):
                self.memory.append(n_memory)
                n_memory=0
                if self.beta>3:
                    remove_value = self.beta-1
                else:
                    remove_value = 1
                zero_indices = np.where(self.current_gamma == 0)[0][:int(remove_value*(self.N**self.dim)*self.n_imgs)]
                self.active_indices = np.delete(self.active_indices, zero_indices, axis=0)
                self.current_cost_vector = np.delete(self.current_cost_vector, zero_indices)
                self.current_gamma = np.delete(self.current_gamma, zero_indices)
                self.iter=0
                self.initialize_model()
                continue
            
            start = time.time()
            #self.m = gp.Model("model")
            #self.new_gamma=self.m.addMVar(shape=best_children.shape[0], vtype=GRB.CONTINUOUS)
            #self.expr.addTerms(self.current_cost_vector[-best_children.shape[0]:], self.new_gamma.tolist())
            
            
            
            #for i in range(self.iter):
            #    print(self.current_cost_vector[self.idx_child[i]:self.idx_child[i+1]])
            #self.m.setObjective(self.expr, GRB.MINIMIZE)
            
            constr = self.m.getConstrs()
            
            #print(A_children[0])
            #print([stacked_arr[0][j] for j in range(0,self.n_imgs)])
            #break
            
            for i in range(len(best_children)):
                self.m.addVar(obj=self.cost_children[i],  vtype=GRB.CONTINUOUS,
                              column=gp.Column([1]*self.n_imgs,
                                               [constr[j] for j in idx[i]]))
                #self.m.update()
            
            
            #self.m.getVars().PStart = self.current_gamma
            #constr.DStart = self.current_kantorovich
            
            self.m.optimize()
           
            self.cost.append(self.m.ObjVal)
            self.time_model.append(time.time()-start)
            self.current_gamma = np.array(self.m.getAttr("X", self.m.getVars()))
            self.current_kantorovich = np.array(self.m.PI)
            
         
    

    def get_mean(self, par):
        
        indices = np.array([[np.unravel_index(self.active_indices.transpose()[i], (self.N, self.N))[j] for i in range(self.n_imgs)] for j in range(2)]) 
        indices = indices.transpose((1,0,2))
        mean = [np.sum([par[i]*indices[i][j] for i in range(self.n_imgs)], axis=0).astype('int') for j in range(2)]        
        mean = np.ravel_multi_index(mean, (self.N, self.N))
        gamma = sp.csr_matrix((self.current_gamma, (self.active_indices.transpose()[0], mean)),
                              shape=(self.N ** 2, self.N ** 2))
        return 1-gamma.todense().transpose().dot(self.imgs[0]).reshape(self.N, self.N)

    def reduce(self):
        non_zero_indices = np.where(self.current_gamma != 0)[0]
        self.active_indices = self.active_indices[non_zero_indices]
        self.current_cost_vector = self.current_cost_vector[non_zero_indices]
        self.current_gamma = self.current_gamma[non_zero_indices]

    def plot(self):
        if self.n_imgs==2:
            plt.close()
            fig, axs = plt.subplots(2, 6)
            axs[0][0].imshow(self.get_mean((1,0)), cmap='gray')
            axs[0][1].imshow(self.get_mean((0.95,0.05)), cmap='gray')
            axs[0][2].imshow(self.get_mean((0.9,0.1)), cmap='gray')
            axs[0][3].imshow(self.get_mean((0.8,0.2)), cmap='gray')
            axs[0][4].imshow(self.get_mean((0.7,0.3)), cmap='gray')
            axs[0][5].imshow(self.get_mean((0.6,0.4)), cmap='gray')
            axs[1][0].imshow(self.get_mean((0.5,0.5)), cmap='gray')
            axs[1][1].imshow(self.get_mean((0.4,0.6)), cmap='gray')
            axs[1][2].imshow(self.get_mean((0.3,0.7)), cmap='gray')
            axs[1][3].imshow(self.get_mean((0.2,0.8)), cmap='gray')
            axs[1][4].imshow(self.get_mean((0.1,0.9)), cmap='gray')
            axs[1][5].imshow(self.get_mean((0,1)), cmap='gray')
            plt.show()
        if self.n_imgs==3:
            plt.close()
            fig, axs = plt.subplots(4, 4)
            axs[0][0].imshow(self.get_mean((1,0,0)), cmap='gray')
            axs[0][1].imshow(self.get_mean((0.67,0.33,0)), cmap='gray')
            axs[0][2].imshow(self.get_mean((0.37,0.63,0)), cmap='gray')
            axs[0][3].imshow(self.get_mean((0,1,0)), cmap='gray')
            axs[1][0].imshow(self.get_mean((0.67,0,0.33)), cmap='gray')
            axs[1][1].imshow(self.get_mean((0.5,0.25,0.25)), cmap='gray')
            axs[1][2].imshow(self.get_mean((0.25,0.5,0.25)), cmap='gray')
            axs[2][0].imshow(self.get_mean((0.33,0,0.67)), cmap='gray')
            axs[2][1].imshow(self.get_mean((0.25,0.25,0.5)), cmap='gray')
            axs[3][0].imshow(self.get_mean((0,0,1)), cmap='gray')  
            plt.show()
        if self.n_imgs>3:
            plt.close()
            fig, axs =plt.subplots(1,self.n_imgs+1)
            for i in range(self.n_imgs):
                axs[i].imshow(1-self.imgs[i].reshape(self.N,self.N), cmap='gray')
            axs[self.n_imgs].imshow(self.get_mean(tuple([1/self.n_imgs])*self.n_imgs), cmap='gray')
            plt.show()
            
    def save(self):
        matplotlib.image.imsave('barycenter.png', self.get_mean(0.5), cmap='Greys')

# %%
path_img1 = "dolphin_64.jpg"
path_img2 = "bird_64.jpg"
path_img3 = "star_64.jpg"
path_img4 = "flower_64.jpg"

dim=3 
n_imgs = 2
#copies: (32,(2,3,4,8,16,24)), (64,(2,3,4,8)), (128,(2,3,4)), 
#14 total tests (dim, n_imgs)

paths = [f"L/L{i}.jpg" for i in range(1,8)]
#paths = [path_img1,path_img2, path_img3]
img_list = [np.array(Image.open(path).convert('L')) for path in paths]
#img_list = [np.random.random((dim,dim)) for i in range(n_imgs)]
img_list = [1-img/255 for img in img_list]
img_list = [(img/np.sum(img))*img.shape[0] for img in img_list]

# %%
ga = Genetic_Algorithm(img_list)
# Out:
# initializing omega...
# omega initialized in 1.071. s
# initializing cost vector...
# cost vector initialized in 0.003. s
# initializing full model...
# Set parameter LPWarmStart to value 2
# Set parameter FeasibilityTol to value 1e-08
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 28672 rows, 28384 columns and 198688 nonzeros
# Model fingerprint: 0x0fa752f5
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-05, 1e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e-04, 2e-01]
# Presolve removed 28672 rows and 28384 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.5865320e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.03 seconds (0.03 work units)
# Optimal objective  1.586532049e+00
# full model initialized in 2.100. s

# %%
turnover_rate = 1 #0.001, 0.01, 0.1, 0.5 , 1 -->5
beta = 10 #1.1, 1.5,2, 2.5, 5 ---> 5
#beta*support + t_r*good_children = k
#we try beta = 3 - t_r/5?

#beta is the memory
#turnover rate is % of children we take
#if we increase turnover rate, we cannot have a too big memory (or it will slow down)
#but also it cannot be too little (or we will restart at every iteration)

parent_to_children = 1 #1, 0.1, 0.01, 0.001 --->4
#ration between parents and their children
#we select p_c*n_active_set parents and approximately 1/p_c children per parent

random_selection = False #true, false ---> 2
#if True, we don't take the top t_r children but just some random

parent_changed = 1 #--->1
#it has to be lower than n_imgs, it's the number of parents that will be randomized (become children)

add_neighbours = True
radius = 2


#idea: if the image are similar then neighbour is a good idea


#claim
#turnover_rate+beta is indipendent from p_c+random_selection+parent_changed

#1st test: dim+n_imgs+turnover_rate+beta = 14*5*5 tests for n min each
#2nd test: dim+n_imgs+p_c+random_selection = 14*4*2 tests for k iteration each

# %%
ga.run(max_iter=20000, max_sample=30, max_runtime=60, beta=beta, turnover_rate=turnover_rate, parent_to_children=parent_to_children, random_selection=random_selection, parent_changed=parent_changed, add_neighbours=add_neighbours, radius=radius)
# Out:
#   0%|                                                 | 0/20000 [00:00<?, ?it/s]
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 28672 rows, 33019 columns and 231133 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-05, 1e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e-04, 2e-01]
# Presolve time: 0.03s
# Presolved: 3296 rows, 3736 columns, 25277 nonzeros
#
# LP warm-start: get starts with basis, then crush them
# Crossover log...
#
#       46 DPushes remaining with DInf 1.5695944e+03                 0s
#        0 DPushes remaining with DInf 1.1865893e+03                 0s
#
#       10 PPushes remaining with PInf 0.0000000e+00                 0s
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 8.3981378e+02      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#       59    1.5865232e+00   0.000000e+00   8.398138e+02      0s
#       87    1.5864884e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 87 iterations and 0.05 seconds (0.08 work units)
# Optimal objective  1.586488413e+00
#   0%|                                         | 1/20000 [00:00<45:05,  7.39it/s]
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 28672 rows, 39284 columns and 274988 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-05, 1e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e-04, 2e-01]
# Presolve time: 0.03s
# Presolved: 3798 rows, 6060 columns, 41888 nonzeros
#
# LP warm-start: get starts with basis, then crush them
# Crossover log...
#
#       27 DPushes remaining with DInf 7.3309133e+03                 0s
#        0 DPushes remaining with DInf 6.4645230e+03                 0s
#
#       17 PPushes remaining with PInf 0.0000000e+00                 0s
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 4.9318724e+03      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#       47    1.5864881e+00   0.000000e+00   4.931872e+03      0s
#      107    1.5864309e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 107 iterations and 0.08 seconds (0.11 work units)
# Optimal objective  1.586430932e+00
#   0%|                                         | 2/20000 [00:00<44:41,  7.46it/s]
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 28672 rows, 49611 columns and 347277 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-05, 2e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e-04, 2e-01]
# Presolve time: 0.04s
# Presolved: 4148 rows, 8105 columns, 56412 nonzeros
#
# LP warm-start: get starts with basis, then crush them
# Crossover log...
#
#       36 DPushes remaining with DInf 6.7508584e+03                 0s
#        0 DPushes remaining with DInf 6.2088291e+03                 0s
#
#       35 PPushes remaining with PInf 0.0000000e+00                 0s
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 5.7846862e+03      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#       74    1.5864281e+00   0.000000e+00   5.784686e+03      0s
#      227    1.5863002e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 227 iterations and 0.10 seconds (0.17 work units)
# Optimal objective  1.586300203e+00
#   0%|                                         | 3/20000 [00:00<51:21,  6.49it/s]
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 28672 rows, 56034 columns and 392238 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-05, 2e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e-04, 2e-01]
# Presolve time: 0.04s
# Presolved: 4260 rows, 9297 columns, 64722 nonzeros
#
# LP warm-start: get starts with basis, then crush them
# Crossover log...
#
#       51 DPushes remaining with DInf 4.7464498e+03                 0s
#        0 DPushes remaining with DInf 4.3401425e+03                 0s
#
#       32 PPushes remaining with PInf 0.0000000e+00                 0s
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 3.1645036e+03      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#       85    1.5863001e+00   0.000000e+00   3.164504e+03      0s
#      341    1.5861302e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 341 iterations and 0.12 seconds (0.22 work units)
# Optimal objective  1.586130231e+00
#   0%|                                         | 4/20000 [00:00<54:38,  6.10it/s]
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 28672 rows, 59178 columns and 414246 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-05, 2e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e-04, 2e-01]
# Presolve time: 0.05s
# Presolved: 4328 rows, 9878 columns, 68803 nonzeros
#
# LP warm-start: get starts with basis, then crush them
# Crossover log...
#
#       58 DPushes remaining with DInf 2.9154005e+03                 0s
#        0 DPushes remaining with DInf 2.1506310e+03                 0s
#
#       35 PPushes remaining with PInf 0.0000000e+00                 0s
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 2.8247066e+03      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#       96    1.5861295e+00   0.000000e+00   2.824707e+03      0s
#      463    1.5859497e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 463 iterations and 0.16 seconds (0.29 work units)
# Optimal objective  1.585949724e+00
#   0%|                                       | 5/20000 [00:00<1:00:12,  5.54it/s]
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 28672 rows, 62318 columns and 436226 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-05, 2e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e-04, 2e-01]
# Presolve time: 0.05s
# Presolved: 4353 rows, 10086 columns, 70346 nonzeros
#
# LP warm-start: get starts with basis, then crush them
# Crossover log...
#
#      100 DPushes remaining with DInf 1.7669558e+03                 0s
#        0 DPushes remaining with DInf 1.5798524e+03                 0s
#
#       46 PPushes remaining with PInf 9.1371126e+00                 0s
#        0 PPushes remaining with PInf 8.6279056e+00                 0s
#
#   Push phase complete: Pinf 8.6279056e+00, Dinf 1.3939681e+04      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      149    1.5838992e+00   0.000000e+00   1.393968e+04      0s
#     1102    1.5858836e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 1102 iterations and 0.30 seconds (0.59 work units)
# Optimal objective  1.585883598e+00
#   0%|                                       | 6/20000 [00:01<1:18:19,  4.25it/s]
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 28672 rows, 67689 columns and 473823 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-05, 2e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e-04, 2e-01]
# Presolve time: 0.06s
# Presolved: 4503 rows, 11770 columns, 82246 nonzeros
#
# LP warm-start: get starts with basis, then crush them
# Crossover log...
#
#       94 DPushes remaining with DInf 1.2981735e+04                 0s
#        0 DPushes remaining with DInf 9.8882471e+03                 0s
#
#       53 PPushes remaining with PInf 0.0000000e+00                 0s
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.7365938e+04      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      148    1.5858797e+00   0.000000e+00   1.736594e+04      0s
#     1497    1.5844441e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 1497 iterations and 0.39 seconds (0.78 work units)
# Optimal objective  1.584444089e+00
#   0%|                                       | 7/20000 [00:01<1:41:47,  3.27it/s]
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 28672 rows, 76088 columns and 532616 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-05, 2e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e-04, 2e-01]
# Presolve time: 0.06s
# Presolved: 4684 rows, 13226 columns, 92342 nonzeros
#
# LP warm-start: get starts with basis, then crush them
# Crossover log...
#
#      122 DPushes remaining with DInf 8.6214833e+03                 0s
#        0 DPushes remaining with DInf 8.2368575e+03                 0s
#
#       92 PPushes remaining with PInf 0.0000000e+00                 0s
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.1812872e+04      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      217    1.5844384e+00   0.000000e+00   1.181287e+04      0s
#     1947    1.5834770e+00   0.000000e+00   0.000000e+00      1s
#
# Solved in 1947 iterations and 0.56 seconds (1.08 work units)
# Optimal objective  1.583476951e+00
#   0%|                                       | 8/20000 [00:02<2:16:26,  2.44it/s]
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 28672 rows, 79855 columns and 558985 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-05, 2e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e-04, 2e-01]
# Presolve time: 0.07s
# Presolved: 4727 rows, 13814 columns, 97001 nonzeros
#
# LP warm-start: get starts with basis, then crush them
# Crossover log...
#
#       61 DPushes remaining with DInf 3.9150228e+03                 0s
#        0 DPushes remaining with DInf 4.1579374e+03                 0s
#
#       49 PPushes remaining with PInf 5.3596526e-02                 0s
#        0 PPushes remaining with PInf 5.3571262e-02                 0s
#
#   Push phase complete: Pinf 5.3571262e-02, Dinf 1.8831621e+03      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      111    1.5834769e+00   0.000000e+00   1.883162e+03      0s
#     1310    1.5831129e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 1310 iterations and 0.48 seconds (0.84 work units)
# Optimal objective  1.583112950e+00
#   0%|                                       | 9/20000 [00:02<2:29:41,  2.23it/s]
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 28672 rows, 83832 columns and 586824 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-05, 2e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e-04, 2e-01]
# Presolve time: 0.07s
# Presolved: 4806 rows, 14717 columns, 102773 nonzeros
#
# LP warm-start: get starts with basis, then crush them
# Crossover log...
#
#      136 DPushes remaining with DInf 6.0451552e+03                 0s
#        0 DPushes remaining with DInf 6.3370287e+03                 0s
#
#       96 PPushes remaining with PInf 1.4401091e+02                 0s
#        0 PPushes remaining with PInf 1.3794049e+02                 0s
#
#   Push phase complete: Pinf 1.3794049e+02, Dinf 1.5488813e+04      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      235    1.5674697e+00   0.000000e+00   1.548881e+04      0s
#     6588    1.5818605e+00   0.000000e+00   0.000000e+00      2s
#
# Solved in 6588 iterations and 2.46 seconds (5.28 work units)
# Optimal objective  1.581860465e+00
#   0%|                                      | 10/20000 [00:05<6:02:59,  1.09s/it]
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 28672 rows, 88004 columns and 616028 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-05, 2e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e-04, 2e-01]
# Presolve time: 0.07s
# Presolved: 4867 rows, 15384 columns, 107985 nonzeros
#
# LP warm-start: get starts with basis, then crush them
# Crossover log...
#
#       62 DPushes remaining with DInf 2.6019457e+03                 0s
#        0 DPushes remaining with DInf 2.5206764e+03                 0s
#
#       66 PPushes remaining with PInf 9.6641849e+00                 0s
#        0 PPushes remaining with PInf 8.9271109e+00                 0s
#
#   Push phase complete: Pinf 8.9271109e+00, Dinf 5.9854034e+03      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      130    1.5816858e+00   0.000000e+00   5.985403e+03      0s
#     3671    1.5812739e+00   0.000000e+00   0.000000e+00      1s
#
# Solved in 3671 iterations and 1.44 seconds (3.17 work units)
# Optimal objective  1.581273893e+00
#   0%|                                      | 11/20000 [00:06<6:45:03,  1.22s/it]
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 28672 rows, 90295 columns and 632065 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-05, 2e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e-04, 2e-01]
# Presolve time: 0.07s
# Presolved: 4913 rows, 15986 columns, 111350 nonzeros
#
# LP warm-start: get starts with basis, then crush them
# Crossover log...
#
#      133 DPushes remaining with DInf 1.6050902e+04                 0s
#        0 DPushes remaining with DInf 8.3453798e+03                 0s
#
#       94 PPushes remaining with PInf 4.4369656e+01                 0s
#        0 PPushes remaining with PInf 4.2134357e+01                 0s
#
#   Push phase complete: Pinf 4.2134357e+01, Dinf 3.3457538e+03      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      230    1.5810714e+00   0.000000e+00   3.345754e+03      0s
#     7057    1.5801158e+00   0.000000e+00   0.000000e+00      3s
#
# Solved in 7057 iterations and 2.94 seconds (6.24 work units)
# Optimal objective  1.580115846e+00
#   0%|                                      | 12/20000 [00:09<9:45:19,  1.76s/it]
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 28672 rows, 92137 columns and 644959 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-05, 2e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e-04, 2e-01]
# Presolve time: 0.08s
# Presolved: 4940 rows, 16287 columns, 112293 nonzeros
#
# LP warm-start: get starts with basis, then crush them
# Crossover log...
#
#      265 DPushes remaining with DInf 2.1966956e+03                 0s
#        0 DPushes remaining with DInf 1.8858800e+03                 0s
#
#      124 PPushes remaining with PInf 2.0399214e-03                 0s
#        0 PPushes remaining with PInf 2.2089830e-04                 0s
#
#   Push phase complete: Pinf 2.2089830e-04, Dinf 5.3276365e+03      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      391    1.5801192e+00   0.000000e+00   5.327636e+03      0s
#     2660    1.5786604e+00   0.000000e+00   0.000000e+00      1s
#
# Solved in 2660 iterations and 1.10 seconds (2.37 work units)
# Optimal objective  1.578660397e+00
#   0%|                                      | 13/20000 [00:10<8:43:40,  1.57s/it]
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 28672 rows, 94912 columns and 664384 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-05, 2e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e-04, 2e-01]
# Presolve time: 0.08s
# Presolved: 4998 rows, 16937 columns, 118513 nonzeros
#
# LP warm-start: get starts with basis, then crush them
# Crossover log...
#
#       82 DPushes remaining with DInf 2.9529977e+03                 0s
#        0 DPushes remaining with DInf 2.8254721e+03                 0s
#
#       73 PPushes remaining with PInf 5.3010945e-02                 0s
#        0 PPushes remaining with PInf 2.7986942e-02                 0s
#
#   Push phase complete: Pinf 2.7986942e-02, Dinf 1.1602328e+04      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      155    1.5786586e+00   0.000000e+00   1.160233e+04      0s
#     2470    1.5780039e+00   0.000000e+00   0.000000e+00      1s
#
# Solved in 2470 iterations and 1.11 seconds (2.41 work units)
# Optimal objective  1.578003950e+00
#   0%|                                      | 14/20000 [00:12<8:02:52,  1.45s/it]
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 28672 rows, 98354 columns and 688478 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-05, 2e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e-04, 2e-01]
# Presolve time: 0.08s
# Presolved: 5092 rows, 17789 columns, 124007 nonzeros
#
# LP warm-start: get starts with basis, then crush them
# Crossover log...
#
#      145 DPushes remaining with DInf 1.2461797e+03                 0s
#        0 DPushes remaining with DInf 1.2305792e+03                 0s
#
#      108 PPushes remaining with PInf 5.1520706e-03                 0s
#        0 PPushes remaining with PInf 1.5718573e-03                 0s
#
#   Push phase complete: Pinf 1.5718573e-03, Dinf 1.4206260e+03      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      256    1.5780043e+00   0.000000e+00   1.420626e+03      0s
#     2469    1.5768784e+00   0.000000e+00   0.000000e+00      1s
#
# Solved in 2469 iterations and 1.15 seconds (2.47 work units)
# Optimal objective  1.576878413e+00
#   0%|                                      | 15/20000 [00:13<7:38:54,  1.38s/it]
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 28672 rows, 101039 columns and 707273 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-05, 2e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e-04, 2e-01]
# Presolve time: 0.09s
# Presolved: 5151 rows, 18319 columns, 127827 nonzeros
#
# LP warm-start: get starts with basis, then crush them
# Crossover log...
#
#      138 DPushes remaining with DInf 1.1950363e+03                 0s
#        0 DPushes remaining with DInf 1.0964571e+03                 0s
#
#      109 PPushes remaining with PInf 0.0000000e+00                 0s
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 7.9310687e+02      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      249    1.5768784e+00   0.000000e+00   7.931069e+02      0s
#     2343    1.5760816e+00   0.000000e+00   0.000000e+00      1s
#
# Solved in 2343 iterations and 1.15 seconds (2.44 work units)
# Optimal objective  1.576081574e+00
#   0%|                                      | 16/20000 [00:14<7:21:43,  1.33s/it]
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 28672 rows, 102758 columns and 719306 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-05, 2e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e-04, 2e-01]
# Presolve time: 0.09s
# Presolved: 5173 rows, 18635 columns, 130460 nonzeros
#
# LP warm-start: get starts with basis, then crush them
# Crossover log...
#
#       89 DPushes remaining with DInf 2.3543352e+02                 0s
#        0 DPushes remaining with DInf 2.0693254e+02                 0s
#
#       80 PPushes remaining with PInf 7.7733093e+00                 0s
#        0 PPushes remaining with PInf 6.6405707e+00                 0s
#
#   Push phase complete: Pinf 6.6405707e+00, Dinf 2.3413298e+03      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      171    1.5760882e+00   0.000000e+00   2.341330e+03      0s
#     4032    1.5756505e+00   0.000000e+00   0.000000e+00      2s
#
# Solved in 4032 iterations and 1.91 seconds (4.20 work units)
# Optimal objective  1.575650464e+00
#   0%|                                      | 17/20000 [00:16<8:25:57,  1.52s/it]
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 28672 rows, 105951 columns and 741657 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-05, 2e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e-04, 2e-01]
# Presolve time: 0.09s
# Presolved: 5250 rows, 19620 columns, 136693 nonzeros
#
# LP warm-start: get starts with basis, then crush them
# Crossover log...
#
#      164 DPushes remaining with DInf 1.7314514e+03                 0s
#        0 DPushes remaining with DInf 1.7394009e+03                 0s
#
#      131 PPushes remaining with PInf 2.2819570e+01                 0s
#        0 PPushes remaining with PInf 2.1580677e+01                 0s
#
#   Push phase complete: Pinf 2.1580677e+01, Dinf 1.6529647e+04      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      297    1.5756625e+00   0.000000e+00   1.652965e+04      0s
#     8294    1.5732325e+00   0.000000e+00   0.000000e+00      4s
#
# Solved in 8294 iterations and 3.93 seconds (8.42 work units)
# Optimal objective  1.573232548e+00
#   0%|                                     | 18/20000 [00:20<12:33:05,  2.26s/it]
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 28672 rows, 108162 columns and 757134 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-05, 2e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e-04, 2e-01]
# Presolve time: 0.10s
# Presolved: 5298 rows, 20415 columns, 141719 nonzeros
#
# LP warm-start: get starts with basis, then crush them
# Crossover log...
#
#      164 DPushes remaining with DInf 1.6003051e+03                 0s
#        0 DPushes remaining with DInf 1.4161648e+03                 0s
#
#      137 PPushes remaining with PInf 2.5177913e+01                 0s
#        0 PPushes remaining with PInf 2.2604887e+01                 0s
#
#   Push phase complete: Pinf 2.2604887e+01, Dinf 4.7269297e+04      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      304    1.5732617e+00   0.000000e+00   4.726930e+04      0s
#     9925    1.5706130e+00   0.000000e+00   0.000000e+00      5s
#
# Solved in 9925 iterations and 5.05 seconds (10.83 work units)
# Optimal objective  1.570613021e+00
#   0%|                                     | 19/20000 [00:25<17:17:35,  3.12s/it]
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 28672 rows, 108953 columns and 762671 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-05, 2e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e-04, 2e-01]
# Presolve time: 0.10s
# Presolved: 5316 rows, 20591 columns, 142802 nonzeros
#
# LP warm-start: get starts with basis, then crush them
# Crossover log...
#
#      157 DPushes remaining with DInf 1.5195944e+03                 0s
#        0 DPushes remaining with DInf 1.4308573e+03                 0s
#
#      129 PPushes remaining with PInf 1.4299613e+00                 0s
#        0 PPushes remaining with PInf 1.2045151e+00                 0s
#
#   Push phase complete: Pinf 1.2045151e+00, Dinf 4.8448082e+03      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      289    1.5706038e+00   0.000000e+00   4.844808e+03      0s
#     4680    1.5701537e+00   0.000000e+00   0.000000e+00      2s
#
# Solved in 4680 iterations and 2.33 seconds (5.03 work units)
# Optimal objective  1.570153737e+00
#   0%|                                     | 20/20000 [00:27<16:03:51,  2.89s/it]
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 28672 rows, 110428 columns and 772996 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-05, 2e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e-04, 2e-01]
# Presolve time: 0.10s
# Presolved: 5338 rows, 21023 columns, 145475 nonzeros
#
# LP warm-start: get starts with basis, then crush them
# Crossover log...
#
#       86 DPushes remaining with DInf 9.2880178e+02                 0s
#        0 DPushes remaining with DInf 8.4254857e+02                 0s
#
#       96 PPushes remaining with PInf 9.0935352e-01                 0s
#        0 PPushes remaining with PInf 8.3356299e-01                 0s
#
#   Push phase complete: Pinf 8.3356299e-01, Dinf 4.0510905e+03      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      185    1.5701566e+00   0.000000e+00   4.051091e+03      0s
#     5209    1.5690786e+00   0.000000e+00   0.000000e+00      3s
#
# Solved in 5209 iterations and 2.82 seconds (6.01 work units)
# Optimal objective  1.569078552e+00
#   0%|                                     | 21/20000 [00:30<16:02:04,  2.89s/it]
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 28672 rows, 111790 columns and 782530 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-05, 2e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e-04, 2e-01]
# Presolve time: 0.11s
# Presolved: 5350 rows, 21346 columns, 147577 nonzeros
#
# LP warm-start: get starts with basis, then crush them
# Crossover log...
#
#      114 DPushes remaining with DInf 2.8260146e+02                 0s
#        0 DPushes remaining with DInf 2.7040742e+02                 0s
#
#       82 PPushes remaining with PInf 8.7643140e-05                 0s
#        0 PPushes remaining with PInf 8.7643140e-05                 0s
#
#   Push phase complete: Pinf 8.7643140e-05, Dinf 2.1953600e+02      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      199    1.5690786e+00   0.000000e+00   2.195360e+02      0s
#     2269    1.5685855e+00   0.000000e+00   0.000000e+00      1s
#
# Solved in 2269 iterations and 1.29 seconds (2.70 work units)
# Optimal objective  1.568585472e+00
#   0%|                                     | 22/20000 [00:32<13:27:15,  2.42s/it]
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 28672 rows, 114252 columns and 799764 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-05, 2e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e-04, 2e-01]
# Presolve time: 0.10s
# Presolved: 5431 rows, 22222 columns, 155180 nonzeros
#
# LP warm-start: get starts with basis, then crush them
# Crossover log...
#
#       40 DPushes remaining with DInf 8.7864878e+02                 0s
#        0 DPushes remaining with DInf 8.6019797e+02                 0s
#
#       55 PPushes remaining with PInf 3.0021631e+00                 0s
#        0 PPushes remaining with PInf 2.6814596e+00                 0s
#
#   Push phase complete: Pinf 2.6814596e+00, Dinf 1.1581856e+05      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#       98    1.5686031e+00   0.000000e+00   1.158186e+05      0s
#     8229    1.5655124e+00   0.000000e+00   0.000000e+00      5s
#
# Solved in 8229 iterations and 4.52 seconds (9.88 work units)
# Optimal objective  1.565512363e+00
#   0%|                                     | 23/20000 [00:36<17:02:52,  3.07s/it]
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 28672 rows, 114828 columns and 803796 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-05, 2e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e-04, 2e-01]
# Presolve time: 0.11s
# Presolved: 5447 rows, 22436 columns, 156037 nonzeros
#
# LP warm-start: get starts with basis, then crush them
# Crossover log...
#
#      111 DPushes remaining with DInf 1.8525997e+03                 0s
#        0 DPushes remaining with DInf 1.1297789e+03                 0s
#
#      121 PPushes remaining with PInf 0.0000000e+00                 0s
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.0355973e+03      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      234    1.5655122e+00   0.000000e+00   1.035597e+03      0s
#     2634    1.5650335e+00   0.000000e+00   0.000000e+00      2s
#
# Solved in 2634 iterations and 1.52 seconds (3.22 work units)
# Optimal objective  1.565033462e+00
#   0%|                                     | 24/20000 [00:38<14:32:45,  2.62s/it]
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 28672 rows, 116914 columns and 818398 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-05, 2e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e-04, 2e-01]
# Presolve time: 0.11s
# Presolved: 5477 rows, 22901 columns, 159867 nonzeros
#
# LP warm-start: get starts with basis, then crush them
# Crossover log...
#
#       42 DPushes remaining with DInf 7.0904629e+02                 0s
#        0 DPushes remaining with DInf 7.0590327e+02                 0s
#
#       53 PPushes remaining with PInf 0.0000000e+00                 0s
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 7.8590464e+02      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#       98    1.5650335e+00   0.000000e+00   7.859046e+02      0s
#     3097    1.5639712e+00   0.000000e+00   0.000000e+00      2s
#
# Solved in 3097 iterations and 1.82 seconds (3.97 work units)
# Optimal objective  1.563971179e+00
#   0%|                                     | 25/20000 [00:40<13:19:37,  2.40s/it]
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 28672 rows, 118494 columns and 829458 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-05, 2e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e-04, 2e-01]
# Presolve time: 0.11s
# Presolved: 5506 rows, 23447 columns, 163160 nonzeros
#
# LP warm-start: get starts with basis, then crush them
# Crossover log...
#
#      139 DPushes remaining with DInf 7.1441299e+02                 0s
#        0 DPushes remaining with DInf 7.0354166e+02                 0s
#
#      106 PPushes remaining with PInf 4.8318567e-02                 0s
#        0 PPushes remaining with PInf 3.3692185e-02                 0s
#
#   Push phase complete: Pinf 3.3692185e-02, Dinf 1.9828174e+04      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      248    1.5639685e+00   0.000000e+00   1.982817e+04      0s
#     4496    1.5622857e+00   0.000000e+00   0.000000e+00      3s
#
# Solved in 4496 iterations and 2.67 seconds (5.79 work units)
# Optimal objective  1.562285662e+00
#   0%|                                     | 26/20000 [00:42<13:52:10,  2.50s/it]
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 28672 rows, 120266 columns and 841862 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-05, 2e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e-04, 2e-01]
# Presolve time: 0.12s
# Presolved: 5534 rows, 24032 columns, 166646 nonzeros
#
# LP warm-start: get starts with basis, then crush them
# Crossover log...
#
#      153 DPushes remaining with DInf 1.2299240e+03                 0s
#        0 DPushes remaining with DInf 1.1388510e+03                 0s
#
#      161 PPushes remaining with PInf 6.0072950e-01                 0s
#        0 PPushes remaining with PInf 4.6316772e-01                 0s
#
#   Push phase complete: Pinf 4.6316772e-01, Dinf 1.3092486e+04      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      316    1.5622747e+00   0.000000e+00   1.309249e+04      0s
#     7293    1.5597586e+00   0.000000e+00   0.000000e+00      4s
#
# Solved in 7293 iterations and 4.45 seconds (9.46 work units)
# Optimal objective  1.559758606e+00
#   0%|                                     | 27/20000 [00:47<17:15:15,  3.11s/it]
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 28672 rows, 120879 columns and 846153 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-05, 2e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e-04, 2e-01]
# Presolve time: 0.12s
# Presolved: 5541 rows, 24182 columns, 168120 nonzeros
#
# LP warm-start: get starts with basis, then crush them
# Crossover log...
#
#      116 DPushes remaining with DInf 1.3111415e+02                 0s
#        0 DPushes remaining with DInf 1.2531990e+02                 0s
#
#       65 PPushes remaining with PInf 3.3008190e-01                 0s
#        0 PPushes remaining with PInf 2.6182847e-01                 0s
#
#   Push phase complete: Pinf 2.6182847e-01, Dinf 1.5911975e+03      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      183    1.5597595e+00   0.000000e+00   1.591197e+03      0s
#     4080    1.5589917e+00   0.000000e+00   0.000000e+00      2s
#
# Solved in 4080 iterations and 2.47 seconds (5.32 work units)
# Optimal objective  1.558991743e+00
#   0%|                                     | 28/20000 [00:50<16:17:30,  2.94s/it]
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 28672 rows, 125806 columns and 880642 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-05, 2e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e-04, 2e-01]
# Presolve time: 0.12s
# Presolved: 5640 rows, 26390 columns, 182487 nonzeros
#
# LP warm-start: get starts with basis, then crush them
# Crossover log...
#
#      158 DPushes remaining with DInf 2.9242255e+03                 0s
#        0 DPushes remaining with DInf 2.7770392e+03                 0s
#
#      152 PPushes remaining with PInf 0.0000000e+00                 0s
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 2.4203126e+04      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      313    1.5589916e+00   0.000000e+00   2.420313e+04      0s
#     6628    1.5550287e+00   0.000000e+00   0.000000e+00      5s
#
# Solved in 6628 iterations and 4.52 seconds (9.78 work units)
# Optimal objective  1.555028730e+00
#   0%|                                     | 29/20000 [00:54<19:04:22,  3.44s/it]
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 28672 rows, 127269 columns and 890883 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-05, 2e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e-04, 2e-01]
# Presolve time: 0.13s
# Presolved: 5663 rows, 26881 columns, 187227 nonzeros
#
# LP warm-start: get starts with basis, then crush them
# Crossover log...
#
#       69 DPushes remaining with DInf 1.0025391e+03                 0s
#        0 DPushes remaining with DInf 7.0338581e+02                 0s
#
#       65 PPushes remaining with PInf 1.0359186e-02                 0s
#        0 PPushes remaining with PInf 9.1342914e-03                 0s
#
#   Push phase complete: Pinf 9.1342914e-03, Dinf 4.2106297e+02      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      137    1.5550287e+00   0.000000e+00   4.210630e+02      0s
#     4684    1.5531927e+00   0.000000e+00   0.000000e+00      3s
#
# Solved in 4684 iterations and 3.22 seconds (7.04 work units)
# Optimal objective  1.553192733e+00
#   0%|                                     | 30/20000 [00:57<18:48:50,  3.39s/it]
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 28672 rows, 129732 columns and 908124 nonzeros
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-05, 2e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e-04, 2e-01]
# Presolve time: 0.13s
# Presolved: 5683 rows, 27369 columns, 190122 nonzeros
#
# LP warm-start: get starts with basis, then crush them
# Crossover log...
#
#       89 DPushes remaining with DInf 1.0760961e+03                 0s
#        0 DPushes remaining with DInf 9.7953179e+02                 0s
#
#       94 PPushes remaining with PInf 6.4091751e+00                 0s
#        0 PPushes remaining with PInf 5.8846371e+00                 0s
#
#   Push phase complete: Pinf 5.8846371e+00, Dinf 3.8451547e+05      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      186    1.5533445e+00   0.000000e+00   3.845155e+05      0s
#     6786    1.5493489e+00   0.000000e+00   2.102101e+04      5s
#    10626    1.5502972e+00   0.000000e+00   0.000000e+00      7s
#
# Solved in 10626 iterations and 7.49 seconds (16.16 work units)
# Optimal objective  1.550297161e+00
#   0%|                                     | 31/20000 [01:05<11:43:06,  2.11s/it]

# %%
ga.plot()

# %%
plot(ga)
# Out:
# the final cost is 1.5649445829941715

# %%
plot(ga)
# Out:
# the final cost is 1.5472526903028838

# %%
plot(ga)
# Out:
# the final cost is 0.0520294772454704

# %%
plot(ga)
# Out:
# the final cost is 0.559293179579594

# %%
plt.scatter(np.array(ga.cost[:-1])-np.array(ga.cost[1:]), ga.time_model[1:])
