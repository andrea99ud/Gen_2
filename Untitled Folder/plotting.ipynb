# %%
import pandas as pd
import ast
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../test/parameters_local.csv")

# %%
df.loc[df["n_imgs"]==3].sort_values("final_cost")
# Out:
#     n_imgs  dim_img  turnover_rate  beta  parent_to_children  \
# 41       3       64           1.00     7                   1
# 37       3       64           1.00     6                   1
# 46       3       64           1.00     9                   1
# 45       3       64           1.00     7                   1
# 36       3       64           1.00     4                   1
# 40       3       64           1.00     5                   1
# 50       3       64           0.10     6                   1
# 54       3       64           0.10     7                   1
# 49       3       64           0.10     4                   1
# 53       3       64           0.10     5                   1
# 43       3       64           1.00     8                   1
# 44       3       64           1.00     9                   1
# 38       3       64           1.00     7                   1
# 47       3       64           1.00    10                   1
# ...

# %%
df.loc[df["n_imgs"]==4].sort_values("final_cost")
# Out:
#      n_imgs  dim_img  turnover_rate  beta  parent_to_children  \
# 74        4       64           1.00     5                   1
# 73        4       64           1.00     4                   1
# 83        4       64           1.00    11                   1
# 82        4       64           1.00     8                   1
# 79        4       64           1.00     9                   1
# 78        4       64           1.00     6                   1
# 75        4       64           1.00     8                   1
# 87        4       64           0.10     8                   1
# 91        4       64           0.10     9                   1
# 95        4       64           0.10    11                   1
# 86        4       64           0.10     5                   1
# 90        4       64           0.10     6                   1
# 94        4       64           0.10     8                   1
# 77        4       64           1.00    12                   1
# ...

# %%
for i in range(35):
    plt.plot(ast.literal_eval(pd.DataFrame(df.loc[df["n_imgs"]==2].obj_cost).iloc[i].values[0
                                                     ]))
plt.yscale("quantile")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[51], line 4
#       1 for i in range(35):
#       2     plt.plot(ast.literal_eval(pd.DataFrame(df.loc[df["n_imgs"]==2].obj_cost).iloc[i].values[0
#       3                                                      ]))
# ----> 4 plt.yscale("quantile")
#       5 plt.show()
#
# File /opt/anaconda3/envs/IRL/lib/python3.11/site-packages/matplotlib/pyplot.py:3113, in yscale(value, **kwargs)
#    3111 @_copy_docstring_and_deprecators(Axes.set_yscale)
#    3112 def yscale(value, **kwargs):
# -> 3113     return gca().set_yscale(value, **kwargs)
#
# File /opt/anaconda3/envs/IRL/lib/python3.11/site-packages/matplotlib/axes/_base.py:74, in _axis_method_wrapper.__set_name__.<locals>.wrapper(self, *args, **kwargs)
#      73 def wrapper(self, *args, **kwargs):
# ---> 74     return get_method(self)(*args, **kwargs)
#
# ...
